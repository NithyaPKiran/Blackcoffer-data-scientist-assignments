# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaPKiran/Blackcoffer-data-scientist-assignments/blob/main/Assignment_1_Extraction_of_textual_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install and check syllapy
# !pip install syllapy
# !pip show syllapy

import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob
import syllapy
# Out:
# Requirement already satisfied: syllapy in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Name: syllapy
# Version: 0.7.2
# Summary: Calculate syllable counts for English words.
# Home-page: https://github.com/mholtzscher/syllapy
# Author: Michael Holtzscher
# Author-email: michael.holtzscher@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to extract article text from a URL
def extract_article_text(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            # Assuming article is contained in <article> tag, adjust based on specific HTML structure
            article = soup.find('article')
            if article:
                # Extract title
                article_title = article.find('h1').get_text().strip()

                # Extract text
                paragraphs = article.find_all('p')
                article_text = ' '.join([p.get_text().strip() for p in paragraphs])

                return article_title, article_text
            else:
                print(f"No article content found for {url}")
                return None, None
        else:
            print(f"Failed to retrieve {url}. Status code: {response.status_code}")
            return None, None
    except Exception as e:
        print(f"Error accessing {url}: {e}")
        return None, None

# %%
# Function to calculate positive score
def positive_score(text):
    words = word_tokenize(text)
    return sum(1 for word in words if word.lower() in positive_words)

# Function to calculate negative score
def negative_score(text):
    words = word_tokenize(text)
    return sum(1 for word in words if word.lower() in negative_words)

# Function to calculate average sentence length
def avg_sentence_length(text):
    sentences = sent_tokenize(text)
    return sum(len(word_tokenize(sentence)) for sentence in sentences) / len(sentences)

# Function to calculate percentage of complex words
def percentage_complex_words(text):
    words = word_tokenize(text)
    english_stopwords = set(stopwords.words("english"))  # Load stopwords correctly

    # Filter out complex words
    complex_words = [word for word in words if word.lower() not in english_stopwords and len(word) > 6]

    # Calculate percentage
    if len(words) > 0:
        return (len(complex_words) / len(words)) * 100
    else:
        return 0.0  # Return 0 if no words are present in the text

# Function to calculate FOG index
def fog_index(avg_sentence_length, percentage_complex_words):
    return 0.4 * (avg_sentence_length + percentage_complex_words)

# Function to calculate average number of words per sentence
def avg_words_per_sentence(text):
    sentences = sent_tokenize(text)
    words_per_sentence = [len(word_tokenize(sentence)) for sentence in sentences]
    return sum(words_per_sentence) / len(sentences)

# Function to count personal pronouns
def personal_pronouns(text):
    pronouns = ['i', 'me', 'my', 'mine', 'myself', 'we', 'us', 'our', 'ours', 'ourselves']
    words = word_tokenize(text.lower())
    return sum(1 for word in words if word in pronouns)

# Function to calculate average word length
def avg_word_length(text):
    words = word_tokenize(text)
    return sum(len(word) for word in words) / len(words)

# Function to compute syllables per word
def syllables_per_word(text):
    words = word_tokenize(text)
    syllable_count = sum(syllapy.count(word) for word in words)
    return syllable_count / len(words) if words else 0

# Function to perform sentiment analysis (using TextBlob)
def sentiment_analysis(text):
    blob = TextBlob(text)
    polarity_score = blob.sentiment.polarity
    subjectivity_score = blob.sentiment.subjectivity
    return polarity_score, subjectivity_score

# %%
# Load Input.xlsx
input_df = pd.read_excel('Input.xlsx')

# %%
# Create a directory to store extracted texts
output_dir = 'extracted_texts'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# Initialize an empty list to store analysis results
results = []

# %%
# Iterate through input_df and extract article text
for index, row in input_df.iterrows():
    url = row['URL']
    url_id = row['URL_ID']

    article_title, article_text = extract_article_text(url)

    if article_text:
        # Save article text to a text file
        file_path = os.path.join(output_dir, f"{url_id}.txt")
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(f"{article_title}\n\n{article_text}")

        print(f"Extracted and saved: {file_path}")

        # Perform text analysis
        avg_sentence_len = avg_sentence_length(article_text)
        percent_complex_words = percentage_complex_words(article_text)
        fog_index_value = fog_index(avg_sentence_len, percent_complex_words)
        avg_words_per_sentence_value = avg_words_per_sentence(article_text)
        complex_word_count = len([word for word in word_tokenize(article_text) if len(word) > 6])
        word_count = len(word_tokenize(article_text))
        syllables_per_word_value = syllables_per_word(article_text)
        personal_pronouns_count = personal_pronouns(article_text)
        avg_word_length_value = avg_word_length(article_text)
        polarity_score, subjectivity_score = sentiment_analysis(article_text)

        # Print or save these variables as required
        print(f"URL_ID: {url_id}")
        print(f"AVG SENTENCE LENGTH: {avg_sentence_len}")
        print(f"PERCENTAGE OF COMPLEX WORDS: {percent_complex_words}")
        print(f"FOG INDEX: {fog_index_value}")
        print(f"AVG NUMBER OF WORDS PER SENTENCE: {avg_words_per_sentence_value}")
        print(f"COMPLEX WORD COUNT: {complex_word_count}")
        print(f"WORD COUNT: {word_count}")
        print(f"SYLLABLE PER WORD: {syllables_per_word_value}")
        print(f"PERSONAL PRONOUNS: {personal_pronouns_count}")
        print(f"AVG WORD LENGTH: {avg_word_length_value}")
        print(f"POLARITY SCORE: {polarity_score}")
        print(f"SUBJECTIVITY SCORE: {subjectivity_score}")
        print("-----------------------")

        # Append results to the list
        results.append([
            url_id, avg_sentence_len, percent_complex_words, fog_index_value, avg_words_per_sentence_value,
            complex_word_count, word_count, syllables_per_word_value, personal_pronouns_count, avg_word_length_value,
            polarity_score, subjectivity_score
        ])
# Out:
# Extracted and saved: extracted_texts/blackassign0001.txt
# URL_ID: blackassign0001
# AVG SENTENCE LENGTH: 15.541666666666666
# PERCENTAGE OF COMPLEX WORDS: 16.621983914209114
# FOG INDEX: 12.865460232350314
# AVG NUMBER OF WORDS PER SENTENCE: 15.541666666666666
# COMPLEX WORD COUNT: 62
# WORD COUNT: 373
# SYLLABLE PER WORD: 1.4101876675603218
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 4.193029490616622
# POLARITY SCORE: 0.2435176892073444
# SUBJECTIVITY SCORE: 0.583195253022839
# -----------------------
# Extracted and saved: extracted_texts/blackassign0002.txt
# URL_ID: blackassign0002
# AVG SENTENCE LENGTH: 20.90909090909091
# PERCENTAGE OF COMPLEX WORDS: 27.888198757763977
# FOG INDEX: 19.518915866741956
# AVG NUMBER OF WORDS PER SENTENCE: 20.90909090909091
# COMPLEX WORD COUNT: 457
# WORD COUNT: 1610
# SYLLABLE PER WORD: 1.6273291925465838
# PERSONAL PRONOUNS: 10
# AVG WORD LENGTH: 4.8826086956521735
# POLARITY SCORE: 0.12183670356489147
# SUBJECTIVITY SCORE: 0.43121502658415417
# -----------------------
# Extracted and saved: extracted_texts/blackassign0003.txt
# URL_ID: blackassign0003
# AVG SENTENCE LENGTH: 21.535714285714285
# PERCENTAGE OF COMPLEX WORDS: 37.147595356550575
# FOG INDEX: 23.473323856905946
# AVG NUMBER OF WORDS PER SENTENCE: 21.535714285714285
# COMPLEX WORD COUNT: 453
# WORD COUNT: 1206
# SYLLABLE PER WORD: 1.8490878938640132
# PERSONAL PRONOUNS: 20
# AVG WORD LENGTH: 5.485074626865671
# POLARITY SCORE: 0.10098725348725347
# SUBJECTIVITY SCORE: 0.4310377585377584
# -----------------------
# Extracted and saved: extracted_texts/blackassign0004.txt
# URL_ID: blackassign0004
# AVG SENTENCE LENGTH: 23.568627450980394
# PERCENTAGE OF COMPLEX WORDS: 36.688851913477535
# FOG INDEX: 24.10299174578317
# AVG NUMBER OF WORDS PER SENTENCE: 23.568627450980394
# COMPLEX WORD COUNT: 446
# WORD COUNT: 1202
# SYLLABLE PER WORD: 1.7462562396006656
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 5.312811980033278
# POLARITY SCORE: 0.04176069831807537
# SUBJECTIVITY SCORE: 0.40874937903626424
# -----------------------
# Extracted and saved: extracted_texts/blackassign0005.txt
# URL_ID: blackassign0005
# AVG SENTENCE LENGTH: 19.789473684210527
# PERCENTAGE OF COMPLEX WORDS: 31.117021276595747
# FOG INDEX: 20.36259798432251
# AVG NUMBER OF WORDS PER SENTENCE: 19.789473684210527
# COMPLEX WORD COUNT: 238
# WORD COUNT: 752
# SYLLABLE PER WORD: 1.6263297872340425
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 5.070478723404255
# POLARITY SCORE: 0.11705387205387208
# SUBJECTIVITY SCORE: 0.5315095398428731
# -----------------------
# Extracted and saved: extracted_texts/blackassign0006.txt
# URL_ID: blackassign0006
# AVG SENTENCE LENGTH: 23.724137931034484
# PERCENTAGE OF COMPLEX WORDS: 38.17829457364341
# FOG INDEX: 24.76097300187116
# AVG NUMBER OF WORDS PER SENTENCE: 23.724137931034484
# COMPLEX WORD COUNT: 794
# WORD COUNT: 2064
# SYLLABLE PER WORD: 1.7727713178294573
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 5.388081395348837
# POLARITY SCORE: 0.12556480263758743
# SUBJECTIVITY SCORE: 0.5681475240652456
# -----------------------
# Extracted and saved: extracted_texts/blackassign0007.txt
# URL_ID: blackassign0007
# AVG SENTENCE LENGTH: 17.661016949152543
# PERCENTAGE OF COMPLEX WORDS: 28.310940499040306
# FOG INDEX: 18.388782979277142
# AVG NUMBER OF WORDS PER SENTENCE: 17.661016949152543
# COMPLEX WORD COUNT: 299
# WORD COUNT: 1042
# SYLLABLE PER WORD: 1.5758157389635317
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 4.768714011516315
# POLARITY SCORE: 0.09054087385482736
# SUBJECTIVITY SCORE: 0.46233992751434594
# -----------------------
# Extracted and saved: extracted_texts/blackassign0008.txt
# URL_ID: blackassign0008
# AVG SENTENCE LENGTH: 18.574468085106382
# PERCENTAGE OF COMPLEX WORDS: 39.175257731958766
# FOG INDEX: 23.09989032682606
# AVG NUMBER OF WORDS PER SENTENCE: 18.574468085106382
# COMPLEX WORD COUNT: 344
# WORD COUNT: 873
# SYLLABLE PER WORD: 1.859106529209622
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 5.595647193585338
# POLARITY SCORE: 0.11367767537122377
# SUBJECTIVITY SCORE: 0.444905273937532
# -----------------------
# Extracted and saved: extracted_texts/blackassign0009.txt
# URL_ID: blackassign0009
# AVG SENTENCE LENGTH: 19.303571428571427
# PERCENTAGE OF COMPLEX WORDS: 38.85291396854764
# FOG INDEX: 23.26259415884763
# AVG NUMBER OF WORDS PER SENTENCE: 19.303571428571427
# COMPLEX WORD COUNT: 423
# WORD COUNT: 1081
# SYLLABLE PER WORD: 1.8408880666049954
# PERSONAL PRONOUNS: 9
# AVG WORD LENGTH: 5.554116558741906
# POLARITY SCORE: 0.08345023032523032
# SUBJECTIVITY SCORE: 0.4227924852924853
# -----------------------
# Extracted and saved: extracted_texts/blackassign0010.txt
# URL_ID: blackassign0010
# AVG SENTENCE LENGTH: 22.164556962025316
# PERCENTAGE OF COMPLEX WORDS: 27.869788692175902
# FOG INDEX: 20.013738261680487
# AVG NUMBER OF WORDS PER SENTENCE: 22.164556962025316
# COMPLEX WORD COUNT: 498
# WORD COUNT: 1751
# SYLLABLE PER WORD: 1.5922330097087378
# PERSONAL PRONOUNS: 16
# AVG WORD LENGTH: 4.8400913763563675
# POLARITY SCORE: 0.13788138231631386
# SUBJECTIVITY SCORE: 0.5040680780406808
# -----------------------
# Extracted and saved: extracted_texts/blackassign0011.txt
# URL_ID: blackassign0011
# AVG SENTENCE LENGTH: 23.363636363636363
# PERCENTAGE OF COMPLEX WORDS: 33.65758754863813
# FOG INDEX: 22.8084895649098
# AVG NUMBER OF WORDS PER SENTENCE: 23.363636363636363
# COMPLEX WORD COUNT: 526
# WORD COUNT: 1542
# SYLLABLE PER WORD: 1.7496757457846952
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 5.286640726329442
# POLARITY SCORE: 0.09990390657729363
# SUBJECTIVITY SCORE: 0.397575059349253
# -----------------------
# Extracted and saved: extracted_texts/blackassign0012.txt
# URL_ID: blackassign0012
# AVG SENTENCE LENGTH: 23.253164556962027
# PERCENTAGE OF COMPLEX WORDS: 31.84540010887316
# FOG INDEX: 22.039425866334074
# AVG NUMBER OF WORDS PER SENTENCE: 23.253164556962027
# COMPLEX WORD COUNT: 586
# WORD COUNT: 1837
# SYLLABLE PER WORD: 1.667936853565596
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 5.137724550898204
# POLARITY SCORE: 0.13603354978354973
# SUBJECTIVITY SCORE: 0.43728021978021986
# -----------------------
# Extracted and saved: extracted_texts/blackassign0013.txt
# URL_ID: blackassign0013
# AVG SENTENCE LENGTH: 27.0
# PERCENTAGE OF COMPLEX WORDS: 32.870370370370374
# FOG INDEX: 23.94814814814815
# AVG NUMBER OF WORDS PER SENTENCE: 27.0
# COMPLEX WORD COUNT: 213
# WORD COUNT: 648
# SYLLABLE PER WORD: 1.6867283950617284
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 5.1234567901234565
# POLARITY SCORE: 0.11180051566080978
# SUBJECTIVITY SCORE: 0.6157037815126051
# -----------------------
# Extracted and saved: extracted_texts/blackassign0014.txt
# URL_ID: blackassign0014
# AVG SENTENCE LENGTH: 17.63235294117647
# PERCENTAGE OF COMPLEX WORDS: 29.357798165137616
# FOG INDEX: 18.796060442525636
# AVG NUMBER OF WORDS PER SENTENCE: 17.63235294117647
# COMPLEX WORD COUNT: 354
# WORD COUNT: 1199
# SYLLABLE PER WORD: 1.5504587155963303
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 4.827356130108424
# POLARITY SCORE: 0.08683542232960838
# SUBJECTIVITY SCORE: 0.4596655089096947
# -----------------------
# Extracted and saved: extracted_texts/blackassign0015.txt
# URL_ID: blackassign0015
# AVG SENTENCE LENGTH: 22.949152542372882
# PERCENTAGE OF COMPLEX WORDS: 31.610044313146236
# FOG INDEX: 21.823678742207647
# AVG NUMBER OF WORDS PER SENTENCE: 22.949152542372882
# COMPLEX WORD COUNT: 435
# WORD COUNT: 1354
# SYLLABLE PER WORD: 1.6144756277695715
# PERSONAL PRONOUNS: 13
# AVG WORD LENGTH: 5.058345642540621
# POLARITY SCORE: 0.13740275702665086
# SUBJECTIVITY SCORE: 0.3837265193017405
# -----------------------
# Extracted and saved: extracted_texts/blackassign0016.txt
# URL_ID: blackassign0016
# AVG SENTENCE LENGTH: 22.949152542372882
# PERCENTAGE OF COMPLEX WORDS: 31.610044313146236
# FOG INDEX: 21.823678742207647
# AVG NUMBER OF WORDS PER SENTENCE: 22.949152542372882
# COMPLEX WORD COUNT: 435
# WORD COUNT: 1354
# SYLLABLE PER WORD: 1.6144756277695715
# PERSONAL PRONOUNS: 13
# AVG WORD LENGTH: 5.058345642540621
# POLARITY SCORE: 0.13740275702665086
# SUBJECTIVITY SCORE: 0.3837265193017405
# -----------------------
# Extracted and saved: extracted_texts/blackassign0017.txt
# URL_ID: blackassign0017
# AVG SENTENCE LENGTH: 19.741935483870968
# PERCENTAGE OF COMPLEX WORDS: 32.59803921568628
# FOG INDEX: 20.9359898798229
# AVG NUMBER OF WORDS PER SENTENCE: 19.741935483870968
# COMPLEX WORD COUNT: 403
# WORD COUNT: 1224
# SYLLABLE PER WORD: 1.6160130718954249
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 4.98937908496732
# POLARITY SCORE: 0.07945426685525693
# SUBJECTIVITY SCORE: 0.46351817599342343
# -----------------------
# Extracted and saved: extracted_texts/blackassign0018.txt
# URL_ID: blackassign0018
# AVG SENTENCE LENGTH: 27.227272727272727
# PERCENTAGE OF COMPLEX WORDS: 32.80467445742905
# FOG INDEX: 24.012778873880713
# AVG NUMBER OF WORDS PER SENTENCE: 27.227272727272727
# COMPLEX WORD COUNT: 398
# WORD COUNT: 1198
# SYLLABLE PER WORD: 1.6093489148580968
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 5.005008347245409
# POLARITY SCORE: 0.0976302269159412
# SUBJECTIVITY SCORE: 0.3060886732315304
# -----------------------
# Extracted and saved: extracted_texts/blackassign0019.txt
# URL_ID: blackassign0019
# AVG SENTENCE LENGTH: 20.30851063829787
# PERCENTAGE OF COMPLEX WORDS: 29.229963331587218
# FOG INDEX: 19.815389587954037
# AVG NUMBER OF WORDS PER SENTENCE: 20.30851063829787
# COMPLEX WORD COUNT: 567
# WORD COUNT: 1909
# SYLLABLE PER WORD: 1.5489785227867994
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 4.789942378208486
# POLARITY SCORE: 0.18399029016498897
# SUBJECTIVITY SCORE: 0.5116761652002615
# -----------------------
# Extracted and saved: extracted_texts/blackassign0020.txt
# URL_ID: blackassign0020
# AVG SENTENCE LENGTH: 23.32
# PERCENTAGE OF COMPLEX WORDS: 20.926243567753
# FOG INDEX: 17.6984974271012
# AVG NUMBER OF WORDS PER SENTENCE: 23.32
# COMPLEX WORD COUNT: 127
# WORD COUNT: 583
# SYLLABLE PER WORD: 1.4665523156089193
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.485420240137222
# POLARITY SCORE: 0.18530778164924508
# SUBJECTIVITY SCORE: 0.45842044134727067
# -----------------------
# Extracted and saved: extracted_texts/blackassign0021.txt
# URL_ID: blackassign0021
# AVG SENTENCE LENGTH: 23.551020408163264
# PERCENTAGE OF COMPLEX WORDS: 32.755632582322356
# FOG INDEX: 22.52266119619425
# AVG NUMBER OF WORDS PER SENTENCE: 23.551020408163264
# COMPLEX WORD COUNT: 388
# WORD COUNT: 1154
# SYLLABLE PER WORD: 1.6629116117850953
# PERSONAL PRONOUNS: 12
# AVG WORD LENGTH: 5.013864818024263
# POLARITY SCORE: 0.015087719298245608
# SUBJECTIVITY SCORE: 0.5669364699627857
# -----------------------
# Extracted and saved: extracted_texts/blackassign0022.txt
# URL_ID: blackassign0022
# AVG SENTENCE LENGTH: 17.46153846153846
# PERCENTAGE OF COMPLEX WORDS: 23.348017621145374
# FOG INDEX: 16.323822433073534
# AVG NUMBER OF WORDS PER SENTENCE: 17.46153846153846
# COMPLEX WORD COUNT: 110
# WORD COUNT: 454
# SYLLABLE PER WORD: 1.5220264317180616
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 4.557268722466961
# POLARITY SCORE: 0.012821548821548826
# SUBJECTIVITY SCORE: 0.5164814814814815
# -----------------------
# Extracted and saved: extracted_texts/blackassign0023.txt
# URL_ID: blackassign0023
# AVG SENTENCE LENGTH: 23.984126984126984
# PERCENTAGE OF COMPLEX WORDS: 22.17074784910655
# FOG INDEX: 18.461949933293415
# AVG NUMBER OF WORDS PER SENTENCE: 23.984126984126984
# COMPLEX WORD COUNT: 338
# WORD COUNT: 1511
# SYLLABLE PER WORD: 1.5135671740569159
# PERSONAL PRONOUNS: 9
# AVG WORD LENGTH: 4.6075446724023825
# POLARITY SCORE: 0.15426631393298057
# SUBJECTIVITY SCORE: 0.4048683127572017
# -----------------------
# Extracted and saved: extracted_texts/blackassign0024.txt
# URL_ID: blackassign0024
# AVG SENTENCE LENGTH: 30.95
# PERCENTAGE OF COMPLEX WORDS: 27.948303715670438
# FOG INDEX: 23.559321486268175
# AVG NUMBER OF WORDS PER SENTENCE: 30.95
# COMPLEX WORD COUNT: 176
# WORD COUNT: 619
# SYLLABLE PER WORD: 1.5783521809369951
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.78513731825525
# POLARITY SCORE: 0.0913095238095238
# SUBJECTIVITY SCORE: 0.5600793650793651
# -----------------------
# Extracted and saved: extracted_texts/blackassign0025.txt
# URL_ID: blackassign0025
# AVG SENTENCE LENGTH: 46.0
# PERCENTAGE OF COMPLEX WORDS: 21.043478260869566
# FOG INDEX: 26.817391304347826
# AVG NUMBER OF WORDS PER SENTENCE: 46.0
# COMPLEX WORD COUNT: 245
# WORD COUNT: 1150
# SYLLABLE PER WORD: 1.4208695652173913
# PERSONAL PRONOUNS: 14
# AVG WORD LENGTH: 4.350434782608696
# POLARITY SCORE: 0.07579020013802623
# SUBJECTIVITY SCORE: 0.43256038647342987
# -----------------------
# Extracted and saved: extracted_texts/blackassign0026.txt
# URL_ID: blackassign0026
# AVG SENTENCE LENGTH: 24.975
# PERCENTAGE OF COMPLEX WORDS: 27.32732732732733
# FOG INDEX: 20.920930930930936
# AVG NUMBER OF WORDS PER SENTENCE: 24.975
# COMPLEX WORD COUNT: 277
# WORD COUNT: 999
# SYLLABLE PER WORD: 1.5285285285285286
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 4.708708708708708
# POLARITY SCORE: 0.13522418058132343
# SUBJECTIVITY SCORE: 0.42674242424242426
# -----------------------
# Extracted and saved: extracted_texts/blackassign0027.txt
# URL_ID: blackassign0027
# AVG SENTENCE LENGTH: 28.096153846153847
# PERCENTAGE OF COMPLEX WORDS: 19.849418206707732
# FOG INDEX: 19.178228821144632
# AVG NUMBER OF WORDS PER SENTENCE: 28.096153846153847
# COMPLEX WORD COUNT: 294
# WORD COUNT: 1461
# SYLLABLE PER WORD: 1.4031485284052019
# PERSONAL PRONOUNS: 32
# AVG WORD LENGTH: 4.28062970568104
# POLARITY SCORE: 0.09198756747367857
# SUBJECTIVITY SCORE: 0.45257953466286777
# -----------------------
# Extracted and saved: extracted_texts/blackassign0028.txt
# URL_ID: blackassign0028
# AVG SENTENCE LENGTH: 32.63157894736842
# PERCENTAGE OF COMPLEX WORDS: 28.064516129032256
# FOG INDEX: 24.27843803056027
# AVG NUMBER OF WORDS PER SENTENCE: 32.63157894736842
# COMPLEX WORD COUNT: 356
# WORD COUNT: 1240
# SYLLABLE PER WORD: 1.520967741935484
# PERSONAL PRONOUNS: 17
# AVG WORD LENGTH: 4.835483870967742
# POLARITY SCORE: 0.10363295654962323
# SUBJECTIVITY SCORE: 0.4291121532788199
# -----------------------
# Extracted and saved: extracted_texts/blackassign0029.txt
# URL_ID: blackassign0029
# AVG SENTENCE LENGTH: 26.546666666666667
# PERCENTAGE OF COMPLEX WORDS: 34.00301356102461
# FOG INDEX: 24.21987209107651
# AVG NUMBER OF WORDS PER SENTENCE: 26.546666666666667
# COMPLEX WORD COUNT: 690
# WORD COUNT: 1991
# SYLLABLE PER WORD: 1.6810647915620291
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 5.1622300351582115
# POLARITY SCORE: 0.13693643937761585
# SUBJECTIVITY SCORE: 0.46336424033482865
# -----------------------
# Extracted and saved: extracted_texts/blackassign0030.txt
# URL_ID: blackassign0030
# AVG SENTENCE LENGTH: 20.620253164556964
# PERCENTAGE OF COMPLEX WORDS: 20.441988950276244
# FOG INDEX: 16.424896845933286
# AVG NUMBER OF WORDS PER SENTENCE: 20.620253164556964
# COMPLEX WORD COUNT: 340
# WORD COUNT: 1629
# SYLLABLE PER WORD: 1.3953345610804175
# PERSONAL PRONOUNS: 10
# AVG WORD LENGTH: 4.295273173726212
# POLARITY SCORE: 0.07469251007613077
# SUBJECTIVITY SCORE: 0.43359613375130607
# -----------------------
# Extracted and saved: extracted_texts/blackassign0031.txt
# URL_ID: blackassign0031
# AVG SENTENCE LENGTH: 22.607142857142858
# PERCENTAGE OF COMPLEX WORDS: 31.648235913638757
# FOG INDEX: 21.70215150831265
# AVG NUMBER OF WORDS PER SENTENCE: 22.607142857142858
# COMPLEX WORD COUNT: 605
# WORD COUNT: 1899
# SYLLABLE PER WORD: 1.6261190100052658
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.901527119536598
# POLARITY SCORE: 0.11268935609844702
# SUBJECTIVITY SCORE: 0.488862122725759
# -----------------------
# Extracted and saved: extracted_texts/blackassign0032.txt
# URL_ID: blackassign0032
# AVG SENTENCE LENGTH: 19.384615384615383
# PERCENTAGE OF COMPLEX WORDS: 21.99546485260771
# FOG INDEX: 16.55203209488924
# AVG NUMBER OF WORDS PER SENTENCE: 19.384615384615383
# COMPLEX WORD COUNT: 399
# WORD COUNT: 1764
# SYLLABLE PER WORD: 1.4535147392290249
# PERSONAL PRONOUNS: 24
# AVG WORD LENGTH: 4.4229024943310655
# POLARITY SCORE: 0.14641465951306376
# SUBJECTIVITY SCORE: 0.5008115156120474
# -----------------------
# Extracted and saved: extracted_texts/blackassign0033.txt
# URL_ID: blackassign0033
# AVG SENTENCE LENGTH: 25.31578947368421
# PERCENTAGE OF COMPLEX WORDS: 24.584199584199585
# FOG INDEX: 19.959995623153517
# AVG NUMBER OF WORDS PER SENTENCE: 25.31578947368421
# COMPLEX WORD COUNT: 477
# WORD COUNT: 1924
# SYLLABLE PER WORD: 1.4896049896049897
# PERSONAL PRONOUNS: 19
# AVG WORD LENGTH: 4.585239085239086
# POLARITY SCORE: 0.05467606111836885
# SUBJECTIVITY SCORE: 0.5109679226099346
# -----------------------
# Extracted and saved: extracted_texts/blackassign0034.txt
# URL_ID: blackassign0034
# AVG SENTENCE LENGTH: 25.654545454545456
# PERCENTAGE OF COMPLEX WORDS: 23.10418143160879
# FOG INDEX: 19.5034907544617
# AVG NUMBER OF WORDS PER SENTENCE: 25.654545454545456
# COMPLEX WORD COUNT: 331
# WORD COUNT: 1411
# SYLLABLE PER WORD: 1.4514528703047485
# PERSONAL PRONOUNS: 36
# AVG WORD LENGTH: 4.471296952515946
# POLARITY SCORE: 0.11950362792343922
# SUBJECTIVITY SCORE: 0.45930167578752484
# -----------------------
# Extracted and saved: extracted_texts/blackassign0035.txt
# URL_ID: blackassign0035
# AVG SENTENCE LENGTH: 18.863636363636363
# PERCENTAGE OF COMPLEX WORDS: 24.216867469879517
# FOG INDEX: 17.23220153340635
# AVG NUMBER OF WORDS PER SENTENCE: 18.863636363636363
# COMPLEX WORD COUNT: 201
# WORD COUNT: 830
# SYLLABLE PER WORD: 1.4493975903614458
# PERSONAL PRONOUNS: 11
# AVG WORD LENGTH: 4.553012048192771
# POLARITY SCORE: 0.1491084283363695
# SUBJECTIVITY SCORE: 0.4230386035533094
# -----------------------
# Failed to retrieve https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/. Status code: 404
# Extracted and saved: extracted_texts/blackassign0037.txt
# URL_ID: blackassign0037
# AVG SENTENCE LENGTH: 22.571428571428573
# PERCENTAGE OF COMPLEX WORDS: 23.16455696202532
# FOG INDEX: 18.29439421338156
# AVG NUMBER OF WORDS PER SENTENCE: 22.571428571428573
# COMPLEX WORD COUNT: 185
# WORD COUNT: 790
# SYLLABLE PER WORD: 1.379746835443038
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.355696202531646
# POLARITY SCORE: 0.1933409660514924
# SUBJECTIVITY SCORE: 0.5740308726361358
# -----------------------
# Extracted and saved: extracted_texts/blackassign0038.txt
# URL_ID: blackassign0038
# AVG SENTENCE LENGTH: 30.0625
# PERCENTAGE OF COMPLEX WORDS: 24.365904365904367
# FOG INDEX: 21.771361746361748
# AVG NUMBER OF WORDS PER SENTENCE: 30.0625
# COMPLEX WORD COUNT: 588
# WORD COUNT: 2405
# SYLLABLE PER WORD: 1.5126819126819127
# PERSONAL PRONOUNS: 12
# AVG WORD LENGTH: 4.507276507276507
# POLARITY SCORE: 0.1685887445887446
# SUBJECTIVITY SCORE: 0.5311564854898188
# -----------------------
# Extracted and saved: extracted_texts/blackassign0039.txt
# URL_ID: blackassign0039
# AVG SENTENCE LENGTH: 24.7
# PERCENTAGE OF COMPLEX WORDS: 25.01124606387764
# FOG INDEX: 19.884498425551058
# AVG NUMBER OF WORDS PER SENTENCE: 24.7
# COMPLEX WORD COUNT: 561
# WORD COUNT: 2223
# SYLLABLE PER WORD: 1.4543409806567702
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.405757984705353
# POLARITY SCORE: 0.12084157564290018
# SUBJECTIVITY SCORE: 0.4682307023366626
# -----------------------
# Extracted and saved: extracted_texts/blackassign0040.txt
# URL_ID: blackassign0040
# AVG SENTENCE LENGTH: 22.56140350877193
# PERCENTAGE OF COMPLEX WORDS: 31.804043545878695
# FOG INDEX: 21.746178821860255
# AVG NUMBER OF WORDS PER SENTENCE: 22.56140350877193
# COMPLEX WORD COUNT: 415
# WORD COUNT: 1286
# SYLLABLE PER WORD: 1.646189735614308
# PERSONAL PRONOUNS: 11
# AVG WORD LENGTH: 5.031881804043546
# POLARITY SCORE: 0.11639375561545375
# SUBJECTIVITY SCORE: 0.41973403169157875
# -----------------------
# Extracted and saved: extracted_texts/blackassign0041.txt
# URL_ID: blackassign0041
# AVG SENTENCE LENGTH: 17.5
# PERCENTAGE OF COMPLEX WORDS: 23.285714285714285
# FOG INDEX: 16.314285714285713
# AVG NUMBER OF WORDS PER SENTENCE: 17.5
# COMPLEX WORD COUNT: 328
# WORD COUNT: 1400
# SYLLABLE PER WORD: 1.4621428571428572
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 4.460714285714285
# POLARITY SCORE: 0.10607930070203922
# SUBJECTIVITY SCORE: 0.3785477329687856
# -----------------------
# Extracted and saved: extracted_texts/blackassign0042.txt
# URL_ID: blackassign0042
# AVG SENTENCE LENGTH: 29.783333333333335
# PERCENTAGE OF COMPLEX WORDS: 21.768326804700617
# FOG INDEX: 20.62066405521358
# AVG NUMBER OF WORDS PER SENTENCE: 29.783333333333335
# COMPLEX WORD COUNT: 392
# WORD COUNT: 1787
# SYLLABLE PER WORD: 1.4857302742025742
# PERSONAL PRONOUNS: 34
# AVG WORD LENGTH: 4.513150531617236
# POLARITY SCORE: 0.1610503569278404
# SUBJECTIVITY SCORE: 0.3904880880708694
# -----------------------
# Extracted and saved: extracted_texts/blackassign0043.txt
# URL_ID: blackassign0043
# AVG SENTENCE LENGTH: 21.9
# PERCENTAGE OF COMPLEX WORDS: 25.28538812785388
# FOG INDEX: 18.874155251141556
# AVG NUMBER OF WORDS PER SENTENCE: 21.9
# COMPLEX WORD COUNT: 452
# WORD COUNT: 1752
# SYLLABLE PER WORD: 1.5034246575342465
# PERSONAL PRONOUNS: 15
# AVG WORD LENGTH: 4.59189497716895
# POLARITY SCORE: 0.05924606107532938
# SUBJECTIVITY SCORE: 0.46846029986273896
# -----------------------
# Extracted and saved: extracted_texts/blackassign0044.txt
# URL_ID: blackassign0044
# AVG SENTENCE LENGTH: 26.571428571428573
# PERCENTAGE OF COMPLEX WORDS: 30.824372759856633
# FOG INDEX: 22.958320532514083
# AVG NUMBER OF WORDS PER SENTENCE: 26.571428571428573
# COMPLEX WORD COUNT: 174
# WORD COUNT: 558
# SYLLABLE PER WORD: 1.60752688172043
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.971326164874552
# POLARITY SCORE: 0.1761308203991131
# SUBJECTIVITY SCORE: 0.5311677753141167
# -----------------------
# Extracted and saved: extracted_texts/blackassign0045.txt
# URL_ID: blackassign0045
# AVG SENTENCE LENGTH: 235.125
# PERCENTAGE OF COMPLEX WORDS: 21.690590111642745
# FOG INDEX: 102.7262360446571
# AVG NUMBER OF WORDS PER SENTENCE: 235.125
# COMPLEX WORD COUNT: 421
# WORD COUNT: 1881
# SYLLABLE PER WORD: 1.531632110579479
# PERSONAL PRONOUNS: 19
# AVG WORD LENGTH: 4.595959595959596
# POLARITY SCORE: 0.1326305759457933
# SUBJECTIVITY SCORE: 0.504171019198193
# -----------------------
# Extracted and saved: extracted_texts/blackassign0046.txt
# URL_ID: blackassign0046
# AVG SENTENCE LENGTH: 18.711111111111112
# PERCENTAGE OF COMPLEX WORDS: 26.60332541567696
# FOG INDEX: 18.12577461071523
# AVG NUMBER OF WORDS PER SENTENCE: 18.711111111111112
# COMPLEX WORD COUNT: 226
# WORD COUNT: 842
# SYLLABLE PER WORD: 1.5273159144893111
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.622327790973872
# POLARITY SCORE: 0.22415371513732166
# SUBJECTIVITY SCORE: 0.4207348662266695
# -----------------------
# Extracted and saved: extracted_texts/blackassign0047.txt
# URL_ID: blackassign0047
# AVG SENTENCE LENGTH: 20.075
# PERCENTAGE OF COMPLEX WORDS: 31.133250311332507
# FOG INDEX: 20.483300124533002
# AVG NUMBER OF WORDS PER SENTENCE: 20.075
# COMPLEX WORD COUNT: 252
# WORD COUNT: 803
# SYLLABLE PER WORD: 1.6276463262764633
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.87173100871731
# POLARITY SCORE: 0.0876316738816739
# SUBJECTIVITY SCORE: 0.34342171717171716
# -----------------------
# Extracted and saved: extracted_texts/blackassign0048.txt
# URL_ID: blackassign0048
# AVG SENTENCE LENGTH: 32.0
# PERCENTAGE OF COMPLEX WORDS: 28.125
# FOG INDEX: 24.05
# AVG NUMBER OF WORDS PER SENTENCE: 32.0
# COMPLEX WORD COUNT: 55
# WORD COUNT: 192
# SYLLABLE PER WORD: 1.5989583333333333
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 4.859375
# POLARITY SCORE: 0.11356437679967092
# SUBJECTIVITY SCORE: 0.36173042643630876
# -----------------------
# Failed to retrieve https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/. Status code: 404
# Extracted and saved: extracted_texts/blackassign0050.txt
# URL_ID: blackassign0050
# AVG SENTENCE LENGTH: 27.581818181818182
# PERCENTAGE OF COMPLEX WORDS: 26.170072511535924
# FOG INDEX: 21.500756277341644
# AVG NUMBER OF WORDS PER SENTENCE: 27.581818181818182
# COMPLEX WORD COUNT: 403
# WORD COUNT: 1517
# SYLLABLE PER WORD: 1.5029663810151614
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 4.695451549110086
# POLARITY SCORE: 0.0441591080876795
# SUBJECTIVITY SCORE: 0.3958860980289551
# -----------------------
# Extracted and saved: extracted_texts/blackassign0051.txt
# URL_ID: blackassign0051
# AVG SENTENCE LENGTH: 28.321428571428573
# PERCENTAGE OF COMPLEX WORDS: 25.598991172761664
# FOG INDEX: 21.568167897676098
# AVG NUMBER OF WORDS PER SENTENCE: 28.321428571428573
# COMPLEX WORD COUNT: 206
# WORD COUNT: 793
# SYLLABLE PER WORD: 1.485498108448928
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 4.572509457755359
# POLARITY SCORE: 0.15593822843822838
# SUBJECTIVITY SCORE: 0.4100283050283051
# -----------------------
# Extracted and saved: extracted_texts/blackassign0052.txt
# URL_ID: blackassign0052
# AVG SENTENCE LENGTH: 19.46788990825688
# PERCENTAGE OF COMPLEX WORDS: 21.86616399622997
# FOG INDEX: 16.533621561794742
# AVG NUMBER OF WORDS PER SENTENCE: 19.46788990825688
# COMPLEX WORD COUNT: 475
# WORD COUNT: 2122
# SYLLABLE PER WORD: 1.4580584354382657
# PERSONAL PRONOUNS: 15
# AVG WORD LENGTH: 4.41234684260132
# POLARITY SCORE: 0.19692985525472845
# SUBJECTIVITY SCORE: 0.4750393599632181
# -----------------------
# Extracted and saved: extracted_texts/blackassign0053.txt
# URL_ID: blackassign0053
# AVG SENTENCE LENGTH: 17.046511627906977
# PERCENTAGE OF COMPLEX WORDS: 25.92087312414734
# FOG INDEX: 17.186953900821727
# AVG NUMBER OF WORDS PER SENTENCE: 17.046511627906977
# COMPLEX WORD COUNT: 190
# WORD COUNT: 733
# SYLLABLE PER WORD: 1.5525238744884038
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 4.635743519781719
# POLARITY SCORE: 0.27188644688644686
# SUBJECTIVITY SCORE: 0.5027521367521367
# -----------------------
# Extracted and saved: extracted_texts/blackassign0054.txt
# URL_ID: blackassign0054
# AVG SENTENCE LENGTH: 25.375
# PERCENTAGE OF COMPLEX WORDS: 19.458128078817737
# FOG INDEX: 17.933251231527095
# AVG NUMBER OF WORDS PER SENTENCE: 25.375
# COMPLEX WORD COUNT: 79
# WORD COUNT: 406
# SYLLABLE PER WORD: 1.4704433497536946
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.58128078817734
# POLARITY SCORE: 0.12852891156462584
# SUBJECTIVITY SCORE: 0.43758503401360543
# -----------------------
# Extracted and saved: extracted_texts/blackassign0055.txt
# URL_ID: blackassign0055
# AVG SENTENCE LENGTH: 26.558823529411764
# PERCENTAGE OF COMPLEX WORDS: 19.82281284606866
# FOG INDEX: 18.55265455019217
# AVG NUMBER OF WORDS PER SENTENCE: 26.558823529411764
# COMPLEX WORD COUNT: 183
# WORD COUNT: 903
# SYLLABLE PER WORD: 1.4363233665559247
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 4.382059800664452
# POLARITY SCORE: 0.16673505892255894
# SUBJECTIVITY SCORE: 0.47165404040404035
# -----------------------
# Extracted and saved: extracted_texts/blackassign0056.txt
# URL_ID: blackassign0056
# AVG SENTENCE LENGTH: 27.94736842105263
# PERCENTAGE OF COMPLEX WORDS: 27.87193973634652
# FOG INDEX: 22.327723262959662
# AVG NUMBER OF WORDS PER SENTENCE: 27.94736842105263
# COMPLEX WORD COUNT: 151
# WORD COUNT: 531
# SYLLABLE PER WORD: 1.5725047080979284
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.732580037664784
# POLARITY SCORE: 0.11930214846881515
# SUBJECTIVITY SCORE: 0.3954986371653039
# -----------------------
# Extracted and saved: extracted_texts/blackassign0057.txt
# URL_ID: blackassign0057
# AVG SENTENCE LENGTH: 15.777777777777779
# PERCENTAGE OF COMPLEX WORDS: 23.708920187793428
# FOG INDEX: 15.794679186228485
# AVG NUMBER OF WORDS PER SENTENCE: 15.777777777777779
# COMPLEX WORD COUNT: 104
# WORD COUNT: 426
# SYLLABLE PER WORD: 1.4906103286384977
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.640845070422535
# POLARITY SCORE: 0.22744949494949493
# SUBJECTIVITY SCORE: 0.5095454545454545
# -----------------------
# Extracted and saved: extracted_texts/blackassign0058.txt
# URL_ID: blackassign0058
# AVG SENTENCE LENGTH: 16.9
# PERCENTAGE OF COMPLEX WORDS: 28.994082840236686
# FOG INDEX: 18.357633136094673
# AVG NUMBER OF WORDS PER SENTENCE: 16.9
# COMPLEX WORD COUNT: 49
# WORD COUNT: 169
# SYLLABLE PER WORD: 1.6923076923076923
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 4.928994082840236
# POLARITY SCORE: 0.04611801242236026
# SUBJECTIVITY SCORE: 0.2803312629399586
# -----------------------
# Extracted and saved: extracted_texts/blackassign0059.txt
# URL_ID: blackassign0059
# AVG SENTENCE LENGTH: 17.072727272727274
# PERCENTAGE OF COMPLEX WORDS: 18.210862619808307
# FOG INDEX: 14.113435957014232
# AVG NUMBER OF WORDS PER SENTENCE: 17.072727272727274
# COMPLEX WORD COUNT: 176
# WORD COUNT: 939
# SYLLABLE PER WORD: 1.3642172523961662
# PERSONAL PRONOUNS: 31
# AVG WORD LENGTH: 4.1501597444089455
# POLARITY SCORE: 0.05008615288220553
# SUBJECTIVITY SCORE: 0.48135964912280715
# -----------------------
# Extracted and saved: extracted_texts/blackassign0060.txt
# URL_ID: blackassign0060
# AVG SENTENCE LENGTH: 21.666666666666668
# PERCENTAGE OF COMPLEX WORDS: 21.025641025641026
# FOG INDEX: 17.076923076923077
# AVG NUMBER OF WORDS PER SENTENCE: 21.666666666666668
# COMPLEX WORD COUNT: 41
# WORD COUNT: 195
# SYLLABLE PER WORD: 1.3846153846153846
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.276923076923077
# POLARITY SCORE: 0.3378571428571428
# SUBJECTIVITY SCORE: 0.45642857142857146
# -----------------------
# Extracted and saved: extracted_texts/blackassign0061.txt
# URL_ID: blackassign0061
# AVG SENTENCE LENGTH: 24.29032258064516
# PERCENTAGE OF COMPLEX WORDS: 31.739707835325365
# FOG INDEX: 22.412012166388212
# AVG NUMBER OF WORDS PER SENTENCE: 24.29032258064516
# COMPLEX WORD COUNT: 242
# WORD COUNT: 753
# SYLLABLE PER WORD: 1.6387782204515273
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 5.086321381142098
# POLARITY SCORE: 0.07827708907254362
# SUBJECTIVITY SCORE: 0.40386822773186404
# -----------------------
# Extracted and saved: extracted_texts/blackassign0062.txt
# URL_ID: blackassign0062
# AVG SENTENCE LENGTH: 31.8
# PERCENTAGE OF COMPLEX WORDS: 18.867924528301888
# FOG INDEX: 20.267169811320755
# AVG NUMBER OF WORDS PER SENTENCE: 31.8
# COMPLEX WORD COUNT: 30
# WORD COUNT: 159
# SYLLABLE PER WORD: 1.3836477987421383
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 4.30188679245283
# POLARITY SCORE: 0.07208273208273208
# SUBJECTIVITY SCORE: 0.508917748917749
# -----------------------
# Extracted and saved: extracted_texts/blackassign0063.txt
# URL_ID: blackassign0063
# AVG SENTENCE LENGTH: 19.238095238095237
# PERCENTAGE OF COMPLEX WORDS: 19.801980198019802
# FOG INDEX: 15.616030174446017
# AVG NUMBER OF WORDS PER SENTENCE: 19.238095238095237
# COMPLEX WORD COUNT: 84
# WORD COUNT: 404
# SYLLABLE PER WORD: 1.4232673267326732
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 4.306930693069307
# POLARITY SCORE: 0.02685479129923574
# SUBJECTIVITY SCORE: 0.6155614344503233
# -----------------------
# Extracted and saved: extracted_texts/blackassign0064.txt
# URL_ID: blackassign0064
# AVG SENTENCE LENGTH: 26.89041095890411
# PERCENTAGE OF COMPLEX WORDS: 28.12022414671421
# FOG INDEX: 22.00425404224733
# AVG NUMBER OF WORDS PER SENTENCE: 26.89041095890411
# COMPLEX WORD COUNT: 557
# WORD COUNT: 1963
# SYLLABLE PER WORD: 1.577687213448803
# PERSONAL PRONOUNS: 21
# AVG WORD LENGTH: 4.784004075394804
# POLARITY SCORE: 0.08833467850417004
# SUBJECTIVITY SCORE: 0.40406645143933273
# -----------------------
# Extracted and saved: extracted_texts/blackassign0065.txt
# URL_ID: blackassign0065
# AVG SENTENCE LENGTH: 27.852941176470587
# PERCENTAGE OF COMPLEX WORDS: 20.221752903907074
# FOG INDEX: 19.229877632151066
# AVG NUMBER OF WORDS PER SENTENCE: 27.852941176470587
# COMPLEX WORD COUNT: 391
# WORD COUNT: 1894
# SYLLABLE PER WORD: 1.43558606124604
# PERSONAL PRONOUNS: 21
# AVG WORD LENGTH: 4.423970432946145
# POLARITY SCORE: 0.12424151623131215
# SUBJECTIVITY SCORE: 0.5002988621355966
# -----------------------
# Extracted and saved: extracted_texts/blackassign0066.txt
# URL_ID: blackassign0066
# AVG SENTENCE LENGTH: 20.506172839506174
# PERCENTAGE OF COMPLEX WORDS: 21.07164358819988
# FOG INDEX: 16.631126571082422
# AVG NUMBER OF WORDS PER SENTENCE: 20.506172839506174
# COMPLEX WORD COUNT: 354
# WORD COUNT: 1661
# SYLLABLE PER WORD: 1.3901264298615292
# PERSONAL PRONOUNS: 33
# AVG WORD LENGTH: 4.33955448524985
# POLARITY SCORE: 0.06454872646733112
# SUBJECTIVITY SCORE: 0.398343484680694
# -----------------------
# Extracted and saved: extracted_texts/blackassign0067.txt
# URL_ID: blackassign0067
# AVG SENTENCE LENGTH: 15.80327868852459
# PERCENTAGE OF COMPLEX WORDS: 19.813278008298756
# FOG INDEX: 14.246622678729338
# AVG NUMBER OF WORDS PER SENTENCE: 15.80327868852459
# COMPLEX WORD COUNT: 198
# WORD COUNT: 964
# SYLLABLE PER WORD: 1.370331950207469
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.1078838174273855
# POLARITY SCORE: 0.18021978021978025
# SUBJECTIVITY SCORE: 0.4836742744435053
# -----------------------
# Extracted and saved: extracted_texts/blackassign0068.txt
# URL_ID: blackassign0068
# AVG SENTENCE LENGTH: 24.676923076923078
# PERCENTAGE OF COMPLEX WORDS: 18.703241895261847
# FOG INDEX: 17.35206598887397
# AVG NUMBER OF WORDS PER SENTENCE: 24.676923076923078
# COMPLEX WORD COUNT: 306
# WORD COUNT: 1604
# SYLLABLE PER WORD: 1.327930174563591
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 4.082294264339152
# POLARITY SCORE: 0.2201765188834155
# SUBJECTIVITY SCORE: 0.43684318555008217
# -----------------------
# Extracted and saved: extracted_texts/blackassign0069.txt
# URL_ID: blackassign0069
# AVG SENTENCE LENGTH: 32.4375
# PERCENTAGE OF COMPLEX WORDS: 18.304431599229286
# FOG INDEX: 20.296772639691717
# AVG NUMBER OF WORDS PER SENTENCE: 32.4375
# COMPLEX WORD COUNT: 99
# WORD COUNT: 519
# SYLLABLE PER WORD: 1.418111753371869
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 4.23121387283237
# POLARITY SCORE: 0.25395622895622894
# SUBJECTIVITY SCORE: 0.5148629148629151
# -----------------------
# Extracted and saved: extracted_texts/blackassign0070.txt
# URL_ID: blackassign0070
# AVG SENTENCE LENGTH: 25.884057971014492
# PERCENTAGE OF COMPLEX WORDS: 25.811870100783874
# FOG INDEX: 20.678371228719346
# AVG NUMBER OF WORDS PER SENTENCE: 25.884057971014492
# COMPLEX WORD COUNT: 464
# WORD COUNT: 1786
# SYLLABLE PER WORD: 1.5347144456886899
# PERSONAL PRONOUNS: 9
# AVG WORD LENGTH: 4.66013437849944
# POLARITY SCORE: 0.12155610912076428
# SUBJECTIVITY SCORE: 0.453966608104539
# -----------------------
# Extracted and saved: extracted_texts/blackassign0071.txt
# URL_ID: blackassign0071
# AVG SENTENCE LENGTH: 15.078947368421053
# PERCENTAGE OF COMPLEX WORDS: 19.546247818499126
# FOG INDEX: 13.850078074768073
# AVG NUMBER OF WORDS PER SENTENCE: 15.078947368421053
# COMPLEX WORD COUNT: 226
# WORD COUNT: 1146
# SYLLABLE PER WORD: 1.382198952879581
# PERSONAL PRONOUNS: 17
# AVG WORD LENGTH: 4.193717277486911
# POLARITY SCORE: 0.07966044837178857
# SUBJECTIVITY SCORE: 0.5755105547373589
# -----------------------
# Extracted and saved: extracted_texts/blackassign0072.txt
# URL_ID: blackassign0072
# AVG SENTENCE LENGTH: 16.911392405063292
# PERCENTAGE OF COMPLEX WORDS: 16.766467065868262
# FOG INDEX: 13.471143788372622
# AVG NUMBER OF WORDS PER SENTENCE: 16.911392405063292
# COMPLEX WORD COUNT: 230
# WORD COUNT: 1336
# SYLLABLE PER WORD: 1.3293413173652695
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 4.118263473053892
# POLARITY SCORE: 0.27596976993044414
# SUBJECTIVITY SCORE: 0.6334269662921347
# -----------------------
# Extracted and saved: extracted_texts/blackassign0073.txt
# URL_ID: blackassign0073
# AVG SENTENCE LENGTH: 26.046511627906977
# PERCENTAGE OF COMPLEX WORDS: 19.107142857142854
# FOG INDEX: 18.06146179401993
# AVG NUMBER OF WORDS PER SENTENCE: 26.046511627906977
# COMPLEX WORD COUNT: 218
# WORD COUNT: 1120
# SYLLABLE PER WORD: 1.36875
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.425892857142857
# POLARITY SCORE: 0.12763469575157887
# SUBJECTIVITY SCORE: 0.47486961811637135
# -----------------------
# Extracted and saved: extracted_texts/blackassign0074.txt
# URL_ID: blackassign0074
# AVG SENTENCE LENGTH: 20.6
# PERCENTAGE OF COMPLEX WORDS: 24.858299595141702
# FOG INDEX: 18.183319838056683
# AVG NUMBER OF WORDS PER SENTENCE: 20.6
# COMPLEX WORD COUNT: 311
# WORD COUNT: 1235
# SYLLABLE PER WORD: 1.5578947368421052
# PERSONAL PRONOUNS: 12
# AVG WORD LENGTH: 4.679352226720648
# POLARITY SCORE: 0.09355238095238093
# SUBJECTIVITY SCORE: 0.3545526695526696
# -----------------------
# Extracted and saved: extracted_texts/blackassign0075.txt
# URL_ID: blackassign0075
# AVG SENTENCE LENGTH: 16.25
# PERCENTAGE OF COMPLEX WORDS: 20.085470085470085
# FOG INDEX: 14.534188034188034
# AVG NUMBER OF WORDS PER SENTENCE: 16.25
# COMPLEX WORD COUNT: 237
# WORD COUNT: 1170
# SYLLABLE PER WORD: 1.3923076923076922
# PERSONAL PRONOUNS: 19
# AVG WORD LENGTH: 4.2324786324786325
# POLARITY SCORE: 0.08261826953003422
# SUBJECTIVITY SCORE: 0.5580835667600373
# -----------------------
# Extracted and saved: extracted_texts/blackassign0076.txt
# URL_ID: blackassign0076
# AVG SENTENCE LENGTH: 25.724137931034484
# PERCENTAGE OF COMPLEX WORDS: 21.31367292225201
# FOG INDEX: 18.815124341314597
# AVG NUMBER OF WORDS PER SENTENCE: 25.724137931034484
# COMPLEX WORD COUNT: 162
# WORD COUNT: 746
# SYLLABLE PER WORD: 1.4235924932975872
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 4.396782841823057
# POLARITY SCORE: 0.04444071313302082
# SUBJECTIVITY SCORE: 0.4772003808157654
# -----------------------
# Extracted and saved: extracted_texts/blackassign0077.txt
# URL_ID: blackassign0077
# AVG SENTENCE LENGTH: 29.181818181818183
# PERCENTAGE OF COMPLEX WORDS: 23.364485981308412
# FOG INDEX: 21.01852166525064
# AVG NUMBER OF WORDS PER SENTENCE: 29.181818181818183
# COMPLEX WORD COUNT: 75
# WORD COUNT: 321
# SYLLABLE PER WORD: 1.442367601246106
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.498442367601246
# POLARITY SCORE: 0.01403318903318903
# SUBJECTIVITY SCORE: 0.3781537906537907
# -----------------------
# Extracted and saved: extracted_texts/blackassign0078.txt
# URL_ID: blackassign0078
# AVG SENTENCE LENGTH: 33.916666666666664
# PERCENTAGE OF COMPLEX WORDS: 27.88697788697789
# FOG INDEX: 24.721457821457822
# AVG NUMBER OF WORDS PER SENTENCE: 33.916666666666664
# COMPLEX WORD COUNT: 227
# WORD COUNT: 814
# SYLLABLE PER WORD: 1.5503685503685503
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.832923832923833
# POLARITY SCORE: 0.09284344347635483
# SUBJECTIVITY SCORE: 0.38957582501886306
# -----------------------
# Extracted and saved: extracted_texts/blackassign0079.txt
# URL_ID: blackassign0079
# AVG SENTENCE LENGTH: 24.482142857142858
# PERCENTAGE OF COMPLEX WORDS: 24.945295404814004
# FOG INDEX: 19.77097530478275
# AVG NUMBER OF WORDS PER SENTENCE: 24.482142857142858
# COMPLEX WORD COUNT: 359
# WORD COUNT: 1371
# SYLLABLE PER WORD: 1.4347191830780452
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 4.575492341356674
# POLARITY SCORE: 0.05494274047465541
# SUBJECTIVITY SCORE: 0.4236375149673021
# -----------------------
# Extracted and saved: extracted_texts/blackassign0080.txt
# URL_ID: blackassign0080
# AVG SENTENCE LENGTH: 20.432989690721648
# PERCENTAGE OF COMPLEX WORDS: 20.686175580222
# FOG INDEX: 16.447666108377458
# AVG NUMBER OF WORDS PER SENTENCE: 20.432989690721648
# COMPLEX WORD COUNT: 833
# WORD COUNT: 3964
# SYLLABLE PER WORD: 1.332744702320888
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 4.358980827447024
# POLARITY SCORE: 0.0509375651086881
# SUBJECTIVITY SCORE: 0.3295961168955822
# -----------------------
# Extracted and saved: extracted_texts/blackassign0081.txt
# URL_ID: blackassign0081
# AVG SENTENCE LENGTH: 23.25609756097561
# PERCENTAGE OF COMPLEX WORDS: 24.803356056633454
# FOG INDEX: 19.223781447043628
# AVG NUMBER OF WORDS PER SENTENCE: 23.25609756097561
# COMPLEX WORD COUNT: 476
# WORD COUNT: 1907
# SYLLABLE PER WORD: 1.4992134242265338
# PERSONAL PRONOUNS: 18
# AVG WORD LENGTH: 4.601468274777137
# POLARITY SCORE: 0.024026950028662362
# SUBJECTIVITY SCORE: 0.4642738045820238
# -----------------------
# Extracted and saved: extracted_texts/blackassign0082.txt
# URL_ID: blackassign0082
# AVG SENTENCE LENGTH: 27.89830508474576
# PERCENTAGE OF COMPLEX WORDS: 29.586877278250306
# FOG INDEX: 22.99407294519843
# AVG NUMBER OF WORDS PER SENTENCE: 27.89830508474576
# COMPLEX WORD COUNT: 494
# WORD COUNT: 1646
# SYLLABLE PER WORD: 1.6452004860267315
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.9829890643985415
# POLARITY SCORE: 0.020758380133380133
# SUBJECTIVITY SCORE: 0.3719696969696968
# -----------------------
# Extracted and saved: extracted_texts/blackassign0083.txt
# URL_ID: blackassign0083
# AVG SENTENCE LENGTH: 22.714285714285715
# PERCENTAGE OF COMPLEX WORDS: 14.465408805031446
# FOG INDEX: 14.871877807726865
# AVG NUMBER OF WORDS PER SENTENCE: 22.714285714285715
# COMPLEX WORD COUNT: 23
# WORD COUNT: 159
# SYLLABLE PER WORD: 1.3144654088050314
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.1257861635220126
# POLARITY SCORE: 0.30720779220779215
# SUBJECTIVITY SCORE: 0.44985930735930735
# -----------------------
# Extracted and saved: extracted_texts/blackassign0084.txt
# URL_ID: blackassign0084
# AVG SENTENCE LENGTH: 25.973684210526315
# PERCENTAGE OF COMPLEX WORDS: 20.56737588652482
# FOG INDEX: 18.616424038820455
# AVG NUMBER OF WORDS PER SENTENCE: 25.973684210526315
# COMPLEX WORD COUNT: 206
# WORD COUNT: 987
# SYLLABLE PER WORD: 1.348530901722391
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.303951367781155
# POLARITY SCORE: 0.17329454253611554
# SUBJECTIVITY SCORE: 0.4787386302835741
# -----------------------
# Extracted and saved: extracted_texts/blackassign0085.txt
# URL_ID: blackassign0085
# AVG SENTENCE LENGTH: 16.89075630252101
# PERCENTAGE OF COMPLEX WORDS: 21.691542288557216
# FOG INDEX: 15.432919436431291
# AVG NUMBER OF WORDS PER SENTENCE: 16.89075630252101
# COMPLEX WORD COUNT: 438
# WORD COUNT: 2010
# SYLLABLE PER WORD: 1.4512437810945273
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 4.506965174129353
# POLARITY SCORE: 0.10960267701647014
# SUBJECTIVITY SCORE: 0.43117604617604605
# -----------------------
# Extracted and saved: extracted_texts/blackassign0086.txt
# URL_ID: blackassign0086
# AVG SENTENCE LENGTH: 21.166666666666668
# PERCENTAGE OF COMPLEX WORDS: 23.20209973753281
# FOG INDEX: 17.747506561679792
# AVG NUMBER OF WORDS PER SENTENCE: 21.166666666666668
# COMPLEX WORD COUNT: 447
# WORD COUNT: 1905
# SYLLABLE PER WORD: 1.4640419947506562
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 4.46246719160105
# POLARITY SCORE: 0.16158404179488525
# SUBJECTIVITY SCORE: 0.4413261504225361
# -----------------------
# Extracted and saved: extracted_texts/blackassign0087.txt
# URL_ID: blackassign0087
# AVG SENTENCE LENGTH: 25.58695652173913
# PERCENTAGE OF COMPLEX WORDS: 22.68479184367035
# FOG INDEX: 19.30869934616379
# AVG NUMBER OF WORDS PER SENTENCE: 25.58695652173913
# COMPLEX WORD COUNT: 271
# WORD COUNT: 1177
# SYLLABLE PER WORD: 1.4502973661852168
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 4.567544604927782
# POLARITY SCORE: 0.09475304998032269
# SUBJECTIVITY SCORE: 0.4424435980685981
# -----------------------
# Extracted and saved: extracted_texts/blackassign0088.txt
# URL_ID: blackassign0088
# AVG SENTENCE LENGTH: 31.516666666666666
# PERCENTAGE OF COMPLEX WORDS: 28.1332628239027
# FOG INDEX: 23.859971796227747
# AVG NUMBER OF WORDS PER SENTENCE: 31.516666666666666
# COMPLEX WORD COUNT: 542
# WORD COUNT: 1891
# SYLLABLE PER WORD: 1.5753569539925965
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 4.843997884717081
# POLARITY SCORE: 0.02981882315215649
# SUBJECTIVITY SCORE: 0.42170835337501994
# -----------------------
# Extracted and saved: extracted_texts/blackassign0089.txt
# URL_ID: blackassign0089
# AVG SENTENCE LENGTH: 22.25
# PERCENTAGE OF COMPLEX WORDS: 25.0
# FOG INDEX: 18.900000000000002
# AVG NUMBER OF WORDS PER SENTENCE: 22.25
# COMPLEX WORD COUNT: 268
# WORD COUNT: 1068
# SYLLABLE PER WORD: 1.4831460674157304
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.5777153558052435
# POLARITY SCORE: 0.08094531419873882
# SUBJECTIVITY SCORE: 0.439496629702109
# -----------------------
# Extracted and saved: extracted_texts/blackassign0090.txt
# URL_ID: blackassign0090
# AVG SENTENCE LENGTH: 18.273972602739725
# PERCENTAGE OF COMPLEX WORDS: 19.940029985007495
# FOG INDEX: 15.285601035098887
# AVG NUMBER OF WORDS PER SENTENCE: 18.273972602739725
# COMPLEX WORD COUNT: 269
# WORD COUNT: 1334
# SYLLABLE PER WORD: 1.4415292353823088
# PERSONAL PRONOUNS: 45
# AVG WORD LENGTH: 4.418290854572714
# POLARITY SCORE: 0.11541107352031724
# SUBJECTIVITY SCORE: 0.44506220670086244
# -----------------------
# Extracted and saved: extracted_texts/blackassign0091.txt
# URL_ID: blackassign0091
# AVG SENTENCE LENGTH: 31.405405405405407
# PERCENTAGE OF COMPLEX WORDS: 25.12908777969019
# FOG INDEX: 22.61379727403824
# AVG NUMBER OF WORDS PER SENTENCE: 31.405405405405407
# COMPLEX WORD COUNT: 296
# WORD COUNT: 1162
# SYLLABLE PER WORD: 1.5740103270223753
# PERSONAL PRONOUNS: 15
# AVG WORD LENGTH: 4.724612736660929
# POLARITY SCORE: 0.07701032059727714
# SUBJECTIVITY SCORE: 0.432465963987703
# -----------------------
# Extracted and saved: extracted_texts/blackassign0092.txt
# URL_ID: blackassign0092
# AVG SENTENCE LENGTH: 24.107142857142858
# PERCENTAGE OF COMPLEX WORDS: 26.37037037037037
# FOG INDEX: 20.191005291005293
# AVG NUMBER OF WORDS PER SENTENCE: 24.107142857142858
# COMPLEX WORD COUNT: 360
# WORD COUNT: 1350
# SYLLABLE PER WORD: 1.5148148148148148
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.697777777777778
# POLARITY SCORE: 0.07886309831267219
# SUBJECTIVITY SCORE: 0.3305119375573921
# -----------------------
# Extracted and saved: extracted_texts/blackassign0093.txt
# URL_ID: blackassign0093
# AVG SENTENCE LENGTH: 20.5
# PERCENTAGE OF COMPLEX WORDS: 15.121951219512194
# FOG INDEX: 14.24878048780488
# AVG NUMBER OF WORDS PER SENTENCE: 20.5
# COMPLEX WORD COUNT: 31
# WORD COUNT: 205
# SYLLABLE PER WORD: 1.2829268292682927
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.097560975609756
# POLARITY SCORE: 0.27325487012987015
# SUBJECTIVITY SCORE: 0.42491206709956714
# -----------------------
# Extracted and saved: extracted_texts/blackassign0094.txt
# URL_ID: blackassign0094
# AVG SENTENCE LENGTH: 20.548387096774192
# PERCENTAGE OF COMPLEX WORDS: 21.664050235478808
# FOG INDEX: 16.8849749329012
# AVG NUMBER OF WORDS PER SENTENCE: 20.548387096774192
# COMPLEX WORD COUNT: 279
# WORD COUNT: 1274
# SYLLABLE PER WORD: 1.4270015698587126
# PERSONAL PRONOUNS: 24
# AVG WORD LENGTH: 4.3791208791208796
# POLARITY SCORE: 0.07338395111832612
# SUBJECTIVITY SCORE: 0.44245129870129857
# -----------------------
# Extracted and saved: extracted_texts/blackassign0095.txt
# URL_ID: blackassign0095
# AVG SENTENCE LENGTH: 20.970588235294116
# PERCENTAGE OF COMPLEX WORDS: 23.983169705469845
# FOG INDEX: 17.981503176305587
# AVG NUMBER OF WORDS PER SENTENCE: 20.970588235294116
# COMPLEX WORD COUNT: 174
# WORD COUNT: 713
# SYLLABLE PER WORD: 1.3955119214586256
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 4.479663394109397
# POLARITY SCORE: 0.05948027068716724
# SUBJECTIVITY SCORE: 0.4058518110242248
# -----------------------
# Extracted and saved: extracted_texts/blackassign0096.txt
# URL_ID: blackassign0096
# AVG SENTENCE LENGTH: 24.1
# PERCENTAGE OF COMPLEX WORDS: 29.62655601659751
# FOG INDEX: 21.490622406639005
# AVG NUMBER OF WORDS PER SENTENCE: 24.1
# COMPLEX WORD COUNT: 362
# WORD COUNT: 1205
# SYLLABLE PER WORD: 1.6190871369294606
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 4.937759336099585
# POLARITY SCORE: 0.05715384749658943
# SUBJECTIVITY SCORE: 0.3914643689643688
# -----------------------
# Extracted and saved: extracted_texts/blackassign0097.txt
# URL_ID: blackassign0097
# AVG SENTENCE LENGTH: 32.270270270270274
# PERCENTAGE OF COMPLEX WORDS: 18.425460636515915
# FOG INDEX: 20.278292362714478
# AVG NUMBER OF WORDS PER SENTENCE: 32.270270270270274
# COMPLEX WORD COUNT: 228
# WORD COUNT: 1194
# SYLLABLE PER WORD: 1.4028475711892798
# PERSONAL PRONOUNS: 13
# AVG WORD LENGTH: 4.293132328308208
# POLARITY SCORE: 0.06488935574229694
# SUBJECTIVITY SCORE: 0.4411360698125404
# -----------------------
# Extracted and saved: extracted_texts/blackassign0098.txt
# URL_ID: blackassign0098
# AVG SENTENCE LENGTH: 32.2
# PERCENTAGE OF COMPLEX WORDS: 22.36024844720497
# FOG INDEX: 21.82409937888199
# AVG NUMBER OF WORDS PER SENTENCE: 32.2
# COMPLEX WORD COUNT: 36
# WORD COUNT: 161
# SYLLABLE PER WORD: 1.5031055900621118
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 4.645962732919255
# POLARITY SCORE: 0.0391025641025641
# SUBJECTIVITY SCORE: 0.375
# -----------------------
# Extracted and saved: extracted_texts/blackassign0099.txt
# URL_ID: blackassign0099
# AVG SENTENCE LENGTH: 22.185185185185187
# PERCENTAGE OF COMPLEX WORDS: 20.20033388981636
# FOG INDEX: 16.95420763000062
# AVG NUMBER OF WORDS PER SENTENCE: 22.185185185185187
# COMPLEX WORD COUNT: 121
# WORD COUNT: 599
# SYLLABLE PER WORD: 1.3873121869782972
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 4.33889816360601
# POLARITY SCORE: 0.08413525498891351
# SUBJECTIVITY SCORE: 0.4035587583148557
# -----------------------
# Extracted and saved: extracted_texts/blackassign0100.txt
# URL_ID: blackassign0100
# AVG SENTENCE LENGTH: 34.333333333333336
# PERCENTAGE OF COMPLEX WORDS: 26.601941747572816
# FOG INDEX: 24.374110032362463
# AVG NUMBER OF WORDS PER SENTENCE: 34.333333333333336
# COMPLEX WORD COUNT: 277
# WORD COUNT: 1030
# SYLLABLE PER WORD: 1.533009708737864
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 4.73495145631068
# POLARITY SCORE: 0.08028635044764076
# SUBJECTIVITY SCORE: 0.422876615618551
# -----------------------

# %%
# Create a DataFrame to store results and save to an Excel file
columns = [
    'URL_ID', 'AVG_SENTENCE_LENGTH', 'PERCENTAGE_OF_COMPLEX_WORDS', 'FOG_INDEX', 'AVG_NUMBER_OF_WORDS_PER_SENTENCE',
    'COMPLEX_WORD_COUNT', 'WORD_COUNT', 'SYLLABLE_PER_WORD', 'PERSONAL_PRONOUNS', 'AVG_WORD_LENGTH',
    'POLARITY_SCORE', 'SUBJECTIVITY_SCORE'
]

# %%
results_df = pd.DataFrame(results, columns=columns)
results_df.to_excel('Assignment 1 - Output_Data_Structure.xlsx', index=False)
print("Results saved to Assignment 1 - Output_Data_Structure.xlsx")
# Out:
# Results saved to Assignment 1 - Output_Data_Structure.xlsx
