# %% [markdown]
# <a href="https://colab.research.google.com/github/NithyaPKiran/Blackcoffer-data-scientist-assignments/blob/main/Text_extraction_and_analysis_Blackcoffer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing and checking syllapy
# !pip install syllapy
# !pip show syllapy
import syllapy
# Out:
# Requirement already satisfied: syllapy in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Name: syllapy
# Version: 0.7.2
# Summary: Calculate syllable counts for English words.
# Home-page: https://github.com/mholtzscher/syllapy
# Author: Michael Holtzscher
# Author-email: michael.holtzscher@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:

# %%
#importing the libraries
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob

# %%
#downloading nltk resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Define function to load stop words from files
def load_words(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            words = set(file.read().splitlines())
    except UnicodeDecodeError:
        with open(file_path, 'r', encoding='latin-1') as file:
            words = set(file.read().splitlines())
    return words

# %%
# Function to extract article text from a URL
def extract_article_text(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            # Assuming article is contained in <article> tag, adjust based on specific HTML structure
            article = soup.find('article')
            if article:
                # Extract title
                article_title = article.find('h1').get_text().strip()

                # Extract text
                paragraphs = article.find_all('p')
                article_text = ' '.join([p.get_text().strip() for p in paragraphs])

                return article_title, article_text
            else:
                print(f"No article content found for {url}")
                return None, None
        else:
            print(f"Failed to retrieve {url}. Status code: {response.status_code}")
            return None, None
    except Exception as e:
        print(f"Error accessing {url}: {e}")
        return None, None

# %%
# Function to clean text using stopwords
def clean_text(text, stopwords_set):
    words = word_tokenize(text)
    cleaned_words = [word for word in words if word.lower() not in stopwords_set and word.isalpha()]
    return ' '.join(cleaned_words)

# %%
# Function to calculate positive score
def positive_score(text, positive_words):
    words = word_tokenize(text)
    return sum(1 for word in words if word.lower() in positive_words)

# %%
# Function to calculate negative score
def negative_score(text, negative_words):
    words = word_tokenize(text)
    return sum(1 for word in words if word.lower() in negative_words)

# %%
# Function to calculate polarity score
def polarity_score(positive_score, negative_score):
    total_score = positive_score + negative_score + 0.000001  # Add small value to avoid division by zero
    return (positive_score - negative_score) / total_score

# %%
# Function to calculate subjectivity score
def subjectivity_score(positive_score, negative_score, total_words):
    total_score = total_words + 0.000001  # Add small value to avoid division by zero
    return (positive_score + negative_score) / total_score

# %%
# Function to calculate average sentence length
def avg_sentence_length(text):
    sentences = sent_tokenize(text)
    return sum(len(word_tokenize(sentence)) for sentence in sentences) / len(sentences)

# %%
# Function to calculate percentage of complex words
def percentage_complex_words(text, stopwords_set):
    words = word_tokenize(text)
    complex_words = [word for word in words if word.lower() not in stopwords_set and len(word) > 6]
    return (len(complex_words) / len(words)) * 100 if len(words) > 0 else 0.0

# %%
# Function to calculate FOG index
def fog_index(avg_sentence_length, percentage_complex_words):
    return 0.4 * (avg_sentence_length + percentage_complex_words)

# %%
# Function to calculate average number of words per sentence
def avg_words_per_sentence(text):
    sentences = sent_tokenize(text)
    words_per_sentence = [len(word_tokenize(sentence)) for sentence in sentences]
    return sum(words_per_sentence) / len(sentences)

# %%
# Function to count personal pronouns
def personal_pronouns(text):
    pronouns = ['i', 'me', 'my', 'mine', 'myself', 'we', 'us', 'our', 'ours', 'ourselves']
    words = word_tokenize(text.lower())
    return sum(1 for word in words if word in pronouns)

# %%
# Function to calculate average word length
def avg_word_length(text):
    words = word_tokenize(text)
    return sum(len(word) for word in words) / len(words)

# %%
# Function to compute syllables per word
def syllables_per_word(text):
    words = word_tokenize(text)
    syllable_count = sum(syllapy.count(word) for word in words)
    return syllable_count / len(words) if words else 0

# %%
# Function to perform sentiment analysis (using TextBlob)
def sentiment_analysis(text):
    blob = TextBlob(text)
    polarity_score = blob.sentiment.polarity
    subjectivity_score = blob.sentiment.subjectivity
    return polarity_score, subjectivity_score

# %%
# Function to load stopwords from multiple files into a set
def load_stopwords(stopword_files):
    stopwords_set = set()
    for file in stopword_files:
        stopwords_set.update(load_words(file))
    return stopwords_set

# %%
# Paths to stopword files
stopword_files = [
    'StopWords_Auditor.txt',
    'StopWords_Currencies.txt',
    'StopWords_DatesandNumbers.txt',
    'StopWords_Generic.txt',
    'StopWords_GenericLong.txt',
    'StopWords_Geographic.txt',
    'StopWords_Names.txt'
]

# %%
# Load stopwords into a set
stopwords_set = load_stopwords(stopword_files)

# %%
# Path to positive and negative words files
positive_words_file = 'positive-words.txt'
negative_words_file = 'negative-words.txt'

# %%
# Load positive and negative words into lists
positive_words = load_words(positive_words_file)
negative_words = load_words(negative_words_file)

# %%
# Load Input.xlsx
input_df = pd.read_excel('Input.xlsx')
input_df.head()
# Out:
#             URL_ID                                                URL
# 0  blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1  blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2  blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3  blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4  blackassign0005  https://insights.blackcoffer.com/ott-platform-...

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   URL_ID  100 non-null    object
#  1   URL     100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
# Create a directory to store extracted texts
output_dir = 'extracted_texts'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
# Initialize an empty list to store analysis results
results = []

# %%
# Iterate through input_df and extract article text
for index, row in input_df.iterrows():
    url = row['URL']
    url_id = row['URL_ID']

    article_title, article_text = extract_article_text(url)

    if article_text:
        # Save article text to a text file
        file_path = os.path.join(output_dir, f"{url_id}.txt")
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(f"{article_title}\n\n{article_text}")

        print(f"Extracted and saved: {file_path}")

        # Perform text cleaning
        cleaned_text = clean_text(article_text, stopwords_set)

        # Custom sentiment analysis
        pos_score = positive_score(cleaned_text, positive_words)
        neg_score = negative_score(cleaned_text, negative_words)
        pol_score = polarity_score(pos_score, neg_score)
        subj_score = subjectivity_score(pos_score, neg_score, len(word_tokenize(cleaned_text)))

        # TextBlob sentiment analysis
        polarity_textblob, subjectivity_textblob = sentiment_analysis(article_text)

        # Calculate other text analysis metrics
        avg_sent_len = avg_sentence_length(article_text)
        percent_complex = percentage_complex_words(cleaned_text, stopwords_set)
        fog_idx = fog_index(avg_sent_len, percent_complex)
        avg_words_per_sent = avg_words_per_sentence(article_text)
        complex_word_count = sum(1 for word in word_tokenize(cleaned_text) if len(word) > 6)
        word_count = len(word_tokenize(cleaned_text))
        syllables_per_word_count = syllables_per_word(cleaned_text)
        personal_pronouns_count = personal_pronouns(article_text)
        avg_word_len = avg_word_length(cleaned_text)

        # Print or save these variables as required
        print(f"URL_ID: {url_id}")
        print(f"URL: {url}")
        print(f"AVG SENTENCE LENGTH: {avg_sent_len}")
        print(f"PERCENTAGE OF COMPLEX WORDS: {percent_complex}")
        print(f"FOG INDEX: {fog_idx}")
        print(f"AVG NUMBER OF WORDS PER SENTENCE: {avg_words_per_sent}")
        print(f"COMPLEX WORD COUNT: {complex_word_count}")
        print(f"WORD COUNT: {word_count}")
        print(f"SYLLABLE PER WORD: {syllables_per_word_count}")
        print(f"PERSONAL PRONOUNS: {personal_pronouns_count}")
        print(f"AVG WORD LENGTH: {avg_word_len}")
        print(f"POLARITY SCORE (Custom): {pol_score}")
        print(f"SUBJECTIVITY SCORE (Custom): {subj_score}")
        print(f"POLARITY SCORE (TextBlob): {polarity_textblob}")
        print(f"SUBJECTIVITY SCORE (TextBlob): {subjectivity_textblob}")
        print("-----------------------")

        # Append results to the list
        results.append([
            url_id, url, avg_sent_len, percent_complex, fog_idx, avg_words_per_sent,
            complex_word_count, word_count, syllables_per_word_count, personal_pronouns_count, avg_word_len,
            pol_score, subj_score, polarity_textblob, subjectivity_textblob
        ])

# Create a DataFrame to store results and save to an Excel file
columns = [
    'URL_ID', 'URL', 'AVG_SENTENCE_LENGTH', 'PERCENTAGE_OF_COMPLEX_WORDS', 'FOG_INDEX', 'AVG_NUMBER_OF_WORDS_PER_SENTENCE',
    'COMPLEX_WORD_COUNT', 'WORD_COUNT', 'SYLLABLE_PER_WORD', 'PERSONAL_PRONOUNS', 'AVG_WORD_LENGTH',
    'POLARITY_SCORE_CUSTOM', 'SUBJECTIVITY_SCORE_CUSTOM', 'POLARITY_SCORE_TEXTBLOB', 'SUBJECTIVITY_SCORE_TEXTBLOB'
]

results_df = pd.DataFrame(results, columns=columns)
results_df.to_excel('Output_Data_Structure.xlsx', index=False)
print("Output_Data_Structure.xlsx")
# Out:
# Extracted and saved: extracted_texts/blackassign0001.txt
# URL_ID: blackassign0001
# URL: https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/
# AVG SENTENCE LENGTH: 15.541666666666666
# PERCENTAGE OF COMPLEX WORDS: 40.52287581699346
# FOG INDEX: 22.425816993464053
# AVG NUMBER OF WORDS PER SENTENCE: 15.541666666666666
# COMPLEX WORD COUNT: 62
# WORD COUNT: 153
# SYLLABLE PER WORD: 2.156862745098039
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 6.522875816993464
# POLARITY SCORE (Custom): 0.7142856122449125
# SUBJECTIVITY SCORE (Custom): 0.04575163368789782
# POLARITY SCORE (TextBlob): 0.2435176892073444
# SUBJECTIVITY SCORE (TextBlob): 0.583195253022839
# -----------------------
# Extracted and saved: extracted_texts/blackassign0002.txt
# URL_ID: blackassign0002
# URL: https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/
# AVG SENTENCE LENGTH: 20.90909090909091
# PERCENTAGE OF COMPLEX WORDS: 57.32044198895028
# FOG INDEX: 31.291813159216474
# AVG NUMBER OF WORDS PER SENTENCE: 20.90909090909091
# COMPLEX WORD COUNT: 415
# WORD COUNT: 724
# SYLLABLE PER WORD: 2.5096685082872927
# PERSONAL PRONOUNS: 10
# AVG WORD LENGTH: 7.468232044198895
# POLARITY SCORE (Custom): 0.2790697641968632
# SUBJECTIVITY SCORE (Custom): 0.1187845302226733
# POLARITY SCORE (TextBlob): 0.12183670356489147
# SUBJECTIVITY SCORE (TextBlob): 0.43121502658415417
# -----------------------
# Extracted and saved: extracted_texts/blackassign0003.txt
# URL_ID: blackassign0003
# URL: https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/
# AVG SENTENCE LENGTH: 21.535714285714285
# PERCENTAGE OF COMPLEX WORDS: 71.84300341296928
# FOG INDEX: 37.35148707947343
# AVG NUMBER OF WORDS PER SENTENCE: 21.535714285714285
# COMPLEX WORD COUNT: 421
# WORD COUNT: 586
# SYLLABLE PER WORD: 2.848122866894198
# PERSONAL PRONOUNS: 20
# AVG WORD LENGTH: 8.303754266211604
# POLARITY SCORE (Custom): 0.22580644797086374
# SUBJECTIVITY SCORE (Custom): 0.1058020476010204
# POLARITY SCORE (TextBlob): 0.10098725348725347
# SUBJECTIVITY SCORE (TextBlob): 0.4310377585377584
# -----------------------
# Extracted and saved: extracted_texts/blackassign0004.txt
# URL_ID: blackassign0004
# URL: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/
# AVG SENTENCE LENGTH: 23.568627450980394
# PERCENTAGE OF COMPLEX WORDS: 72.38421955403086
# FOG INDEX: 38.3811388020045
# AVG NUMBER OF WORDS PER SENTENCE: 23.568627450980394
# COMPLEX WORD COUNT: 422
# WORD COUNT: 583
# SYLLABLE PER WORD: 2.7221269296740993
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 8.147512864493997
# POLARITY SCORE (Custom): -0.35135134818602387
# SUBJECTIVITY SCORE (Custom): 0.19039451082265094
# POLARITY SCORE (TextBlob): 0.04176069831807537
# SUBJECTIVITY SCORE (TextBlob): 0.40874937903626424
# -----------------------
# Extracted and saved: extracted_texts/blackassign0005.txt
# URL_ID: blackassign0005
# URL: https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/
# AVG SENTENCE LENGTH: 19.789473684210527
# PERCENTAGE OF COMPLEX WORDS: 62.09912536443149
# FOG INDEX: 32.75543961945681
# AVG NUMBER OF WORDS PER SENTENCE: 19.789473684210527
# COMPLEX WORD COUNT: 213
# WORD COUNT: 343
# SYLLABLE PER WORD: 2.3644314868804663
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 7.4169096209912535
# POLARITY SCORE (Custom): 0.4482758466111777
# SUBJECTIVITY SCORE (Custom): 0.0845481047097723
# POLARITY SCORE (TextBlob): 0.11705387205387208
# SUBJECTIVITY SCORE (TextBlob): 0.5315095398428731
# -----------------------
# Extracted and saved: extracted_texts/blackassign0006.txt
# URL_ID: blackassign0006
# URL: https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/
# AVG SENTENCE LENGTH: 23.724137931034484
# PERCENTAGE OF COMPLEX WORDS: 72.23300970873787
# FOG INDEX: 38.382859055908945
# AVG NUMBER OF WORDS PER SENTENCE: 23.724137931034484
# COMPLEX WORD COUNT: 744
# WORD COUNT: 1030
# SYLLABLE PER WORD: 2.6388349514563108
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 7.9864077669902915
# POLARITY SCORE (Custom): 0.5357142809311225
# SUBJECTIVITY SCORE (Custom): 0.10873786397209916
# POLARITY SCORE (TextBlob): 0.12556480263758743
# SUBJECTIVITY SCORE (TextBlob): 0.5681475240652456
# -----------------------
# Extracted and saved: extracted_texts/blackassign0007.txt
# URL_ID: blackassign0007
# URL: https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/
# AVG SENTENCE LENGTH: 17.661016949152543
# PERCENTAGE OF COMPLEX WORDS: 57.98687089715536
# FOG INDEX: 30.259155138523166
# AVG NUMBER OF WORDS PER SENTENCE: 17.661016949152543
# COMPLEX WORD COUNT: 265
# WORD COUNT: 457
# SYLLABLE PER WORD: 2.3479212253829322
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 7.185995623632385
# POLARITY SCORE (Custom): -0.30303029843893486
# SUBJECTIVITY SCORE (Custom): 0.14442013097501066
# POLARITY SCORE (TextBlob): 0.09054087385482736
# SUBJECTIVITY SCORE (TextBlob): 0.46233992751434594
# -----------------------
# Extracted and saved: extracted_texts/blackassign0008.txt
# URL_ID: blackassign0008
# URL: https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/
# AVG SENTENCE LENGTH: 18.574468085106382
# PERCENTAGE OF COMPLEX WORDS: 73.1651376146789
# FOG INDEX: 36.69584227991411
# AVG NUMBER OF WORDS PER SENTENCE: 18.574468085106382
# COMPLEX WORD COUNT: 319
# WORD COUNT: 436
# SYLLABLE PER WORD: 2.903669724770642
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 8.40137614678899
# POLARITY SCORE (Custom): 0.5263157756232691
# SUBJECTIVITY SCORE (Custom): 0.0871559631028533
# POLARITY SCORE (TextBlob): 0.11367767537122377
# SUBJECTIVITY SCORE (TextBlob): 0.444905273937532
# -----------------------
# Extracted and saved: extracted_texts/blackassign0009.txt
# URL_ID: blackassign0009
# URL: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/
# AVG SENTENCE LENGTH: 19.303571428571427
# PERCENTAGE OF COMPLEX WORDS: 71.94244604316546
# FOG INDEX: 36.49840698869476
# AVG NUMBER OF WORDS PER SENTENCE: 19.303571428571427
# COMPLEX WORD COUNT: 400
# WORD COUNT: 556
# SYLLABLE PER WORD: 2.8093525179856114
# PERSONAL PRONOUNS: 9
# AVG WORD LENGTH: 8.303956834532373
# POLARITY SCORE (Custom): -0.13636363481404962
# SUBJECTIVITY SCORE (Custom): 0.15827338101029967
# POLARITY SCORE (TextBlob): 0.08345023032523032
# SUBJECTIVITY SCORE (TextBlob): 0.4227924852924853
# -----------------------
# Extracted and saved: extracted_texts/blackassign0010.txt
# URL_ID: blackassign0010
# URL: https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/
# AVG SENTENCE LENGTH: 22.164556962025316
# PERCENTAGE OF COMPLEX WORDS: 68.13509544787078
# FOG INDEX: 36.11986096395844
# AVG NUMBER OF WORDS PER SENTENCE: 22.164556962025316
# COMPLEX WORD COUNT: 464
# WORD COUNT: 681
# SYLLABLE PER WORD: 2.6622613803230544
# PERSONAL PRONOUNS: 16
# AVG WORD LENGTH: 8.08957415565345
# POLARITY SCORE (Custom): -0.06249999951171876
# SUBJECTIVITY SCORE (Custom): 0.18795888371812206
# POLARITY SCORE (TextBlob): 0.13788138231631386
# SUBJECTIVITY SCORE (TextBlob): 0.5040680780406808
# -----------------------
# Extracted and saved: extracted_texts/blackassign0011.txt
# URL_ID: blackassign0011
# URL: https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/
# AVG SENTENCE LENGTH: 23.363636363636363
# PERCENTAGE OF COMPLEX WORDS: 66.30727762803235
# FOG INDEX: 35.86836559666749
# AVG NUMBER OF WORDS PER SENTENCE: 23.363636363636363
# COMPLEX WORD COUNT: 492
# WORD COUNT: 742
# SYLLABLE PER WORD: 2.683288409703504
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 7.950134770889488
# POLARITY SCORE (Custom): 0.518987335202692
# SUBJECTIVITY SCORE (Custom): 0.10646900255192857
# POLARITY SCORE (TextBlob): 0.09990390657729363
# SUBJECTIVITY SCORE (TextBlob): 0.397575059349253
# -----------------------
# Extracted and saved: extracted_texts/blackassign0012.txt
# URL_ID: blackassign0012
# URL: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/
# AVG SENTENCE LENGTH: 23.253164556962027
# PERCENTAGE OF COMPLEX WORDS: 64.62829736211032
# FOG INDEX: 35.15258476762894
# AVG NUMBER OF WORDS PER SENTENCE: 23.253164556962027
# COMPLEX WORD COUNT: 539
# WORD COUNT: 834
# SYLLABLE PER WORD: 2.5059952038369304
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 7.764988009592326
# POLARITY SCORE (Custom): 0.5384615332840237
# SUBJECTIVITY SCORE (Custom): 0.1247002396586328
# POLARITY SCORE (TextBlob): 0.13603354978354973
# SUBJECTIVITY SCORE (TextBlob): 0.43728021978021986
# -----------------------
# Extracted and saved: extracted_texts/blackassign0013.txt
# URL_ID: blackassign0013
# URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/
# AVG SENTENCE LENGTH: 27.0
# PERCENTAGE OF COMPLEX WORDS: 73.35907335907336
# FOG INDEX: 40.14362934362935
# AVG NUMBER OF WORDS PER SENTENCE: 27.0
# COMPLEX WORD COUNT: 190
# WORD COUNT: 259
# SYLLABLE PER WORD: 2.7065637065637067
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 8.243243243243244
# POLARITY SCORE (Custom): 0.49019606881968497
# SUBJECTIVITY SCORE (Custom): 0.19691119615092204
# POLARITY SCORE (TextBlob): 0.11180051566080978
# SUBJECTIVITY SCORE (TextBlob): 0.6157037815126051
# -----------------------
# Extracted and saved: extracted_texts/blackassign0014.txt
# URL_ID: blackassign0014
# URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/
# AVG SENTENCE LENGTH: 17.63235294117647
# PERCENTAGE OF COMPLEX WORDS: 63.21138211382114
# FOG INDEX: 32.33749402199904
# AVG NUMBER OF WORDS PER SENTENCE: 17.63235294117647
# COMPLEX WORD COUNT: 311
# WORD COUNT: 492
# SYLLABLE PER WORD: 2.4004065040650406
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 7.392276422764228
# POLARITY SCORE (Custom): -0.1249999973958334
# SUBJECTIVITY SCORE (Custom): 0.09756097541146143
# POLARITY SCORE (TextBlob): 0.08683542232960838
# SUBJECTIVITY SCORE (TextBlob): 0.4596655089096947
# -----------------------
# Extracted and saved: extracted_texts/blackassign0015.txt
# URL_ID: blackassign0015
# URL: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/
# AVG SENTENCE LENGTH: 22.949152542372882
# PERCENTAGE OF COMPLEX WORDS: 62.7906976744186
# FOG INDEX: 34.29594008671659
# AVG NUMBER OF WORDS PER SENTENCE: 22.949152542372882
# COMPLEX WORD COUNT: 378
# WORD COUNT: 602
# SYLLABLE PER WORD: 2.398671096345515
# PERSONAL PRONOUNS: 13
# AVG WORD LENGTH: 7.485049833887043
# POLARITY SCORE (Custom): 0.11475409647944104
# SUBJECTIVITY SCORE (Custom): 0.1013289034861646
# POLARITY SCORE (TextBlob): 0.13740275702665086
# SUBJECTIVITY SCORE (TextBlob): 0.3837265193017405
# -----------------------
# Extracted and saved: extracted_texts/blackassign0016.txt
# URL_ID: blackassign0016
# URL: https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/
# AVG SENTENCE LENGTH: 22.949152542372882
# PERCENTAGE OF COMPLEX WORDS: 62.7906976744186
# FOG INDEX: 34.29594008671659
# AVG NUMBER OF WORDS PER SENTENCE: 22.949152542372882
# COMPLEX WORD COUNT: 378
# WORD COUNT: 602
# SYLLABLE PER WORD: 2.398671096345515
# PERSONAL PRONOUNS: 13
# AVG WORD LENGTH: 7.485049833887043
# POLARITY SCORE (Custom): 0.11475409647944104
# SUBJECTIVITY SCORE (Custom): 0.1013289034861646
# POLARITY SCORE (TextBlob): 0.13740275702665086
# SUBJECTIVITY SCORE (TextBlob): 0.3837265193017405
# -----------------------
# Extracted and saved: extracted_texts/blackassign0017.txt
# URL_ID: blackassign0017
# URL: https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/
# AVG SENTENCE LENGTH: 19.741935483870968
# PERCENTAGE OF COMPLEX WORDS: 66.2431941923775
# FOG INDEX: 34.39405187049939
# AVG NUMBER OF WORDS PER SENTENCE: 19.741935483870968
# COMPLEX WORD COUNT: 365
# WORD COUNT: 551
# SYLLABLE PER WORD: 2.441016333938294
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 7.442831215970962
# POLARITY SCORE (Custom): 0.55555554526749
# SUBJECTIVITY SCORE (Custom): 0.0980036295862003
# POLARITY SCORE (TextBlob): 0.07945426685525693
# SUBJECTIVITY SCORE (TextBlob): 0.46351817599342343
# -----------------------
# Extracted and saved: extracted_texts/blackassign0018.txt
# URL_ID: blackassign0018
# URL: https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/
# AVG SENTENCE LENGTH: 27.227272727272727
# PERCENTAGE OF COMPLEX WORDS: 66.6003976143141
# FOG INDEX: 37.53106813663474
# AVG NUMBER OF WORDS PER SENTENCE: 27.227272727272727
# COMPLEX WORD COUNT: 335
# WORD COUNT: 503
# SYLLABLE PER WORD: 2.5049701789264414
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.721669980119285
# POLARITY SCORE (Custom): 0.5238095113378688
# SUBJECTIVITY SCORE (Custom): 0.08349900579821272
# POLARITY SCORE (TextBlob): 0.0976302269159412
# SUBJECTIVITY SCORE (TextBlob): 0.3060886732315304
# -----------------------
# Extracted and saved: extracted_texts/blackassign0019.txt
# URL_ID: blackassign0019
# URL: https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/
# AVG SENTENCE LENGTH: 20.30851063829787
# PERCENTAGE OF COMPLEX WORDS: 65.4228855721393
# FOG INDEX: 34.29255848417487
# AVG NUMBER OF WORDS PER SENTENCE: 20.30851063829787
# COMPLEX WORD COUNT: 526
# WORD COUNT: 804
# SYLLABLE PER WORD: 2.415422885572139
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 7.481343283582089
# POLARITY SCORE (Custom): 0.8124999873046878
# SUBJECTIVITY SCORE (Custom): 0.07960198995074379
# POLARITY SCORE (TextBlob): 0.18399029016498897
# SUBJECTIVITY SCORE (TextBlob): 0.5116761652002615
# -----------------------
# Extracted and saved: extracted_texts/blackassign0020.txt
# URL_ID: blackassign0020
# URL: https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/
# AVG SENTENCE LENGTH: 23.32
# PERCENTAGE OF COMPLEX WORDS: 58.46153846153847
# FOG INDEX: 32.71261538461539
# AVG NUMBER OF WORDS PER SENTENCE: 23.32
# COMPLEX WORD COUNT: 114
# WORD COUNT: 195
# SYLLABLE PER WORD: 2.3333333333333335
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.343589743589743
# POLARITY SCORE (Custom): 0.9999998750000157
# SUBJECTIVITY SCORE (Custom): 0.041025640815253124
# POLARITY SCORE (TextBlob): 0.18530778164924508
# SUBJECTIVITY SCORE (TextBlob): 0.45842044134727067
# -----------------------
# Extracted and saved: extracted_texts/blackassign0021.txt
# URL_ID: blackassign0021
# URL: https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/
# AVG SENTENCE LENGTH: 23.551020408163264
# PERCENTAGE OF COMPLEX WORDS: 66.015625
# FOG INDEX: 35.82665816326531
# AVG NUMBER OF WORDS PER SENTENCE: 23.551020408163264
# COMPLEX WORD COUNT: 338
# WORD COUNT: 512
# SYLLABLE PER WORD: 2.5
# PERSONAL PRONOUNS: 12
# AVG WORD LENGTH: 7.556640625
# POLARITY SCORE (Custom): -0.3529411712802769
# SUBJECTIVITY SCORE (Custom): 0.13281249974060058
# POLARITY SCORE (TextBlob): 0.015087719298245608
# SUBJECTIVITY SCORE (TextBlob): 0.5669364699627857
# -----------------------
# Extracted and saved: extracted_texts/blackassign0022.txt
# URL_ID: blackassign0022
# URL: https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/
# AVG SENTENCE LENGTH: 17.46153846153846
# PERCENTAGE OF COMPLEX WORDS: 56.287425149700596
# FOG INDEX: 29.499585444495622
# AVG NUMBER OF WORDS PER SENTENCE: 17.46153846153846
# COMPLEX WORD COUNT: 94
# WORD COUNT: 167
# SYLLABLE PER WORD: 2.3652694610778444
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 7.209580838323354
# POLARITY SCORE (Custom): 0.09090908677685969
# SUBJECTIVITY SCORE (Custom): 0.1317365261572663
# POLARITY SCORE (TextBlob): 0.012821548821548826
# SUBJECTIVITY SCORE (TextBlob): 0.5164814814814815
# -----------------------
# Extracted and saved: extracted_texts/blackassign0023.txt
# URL_ID: blackassign0023
# URL: https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/
# AVG SENTENCE LENGTH: 23.984126984126984
# PERCENTAGE OF COMPLEX WORDS: 48.012718600953896
# FOG INDEX: 28.798738234032353
# AVG NUMBER OF WORDS PER SENTENCE: 23.984126984126984
# COMPLEX WORD COUNT: 302
# WORD COUNT: 629
# SYLLABLE PER WORD: 2.3084260731319555
# PERSONAL PRONOUNS: 9
# AVG WORD LENGTH: 6.993640699523053
# POLARITY SCORE (Custom): 0.30232557436452157
# SUBJECTIVITY SCORE (Custom): 0.06836248001850162
# POLARITY SCORE (TextBlob): 0.15426631393298057
# SUBJECTIVITY SCORE (TextBlob): 0.4048683127572017
# -----------------------
# Extracted and saved: extracted_texts/blackassign0024.txt
# URL_ID: blackassign0024
# URL: https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/
# AVG SENTENCE LENGTH: 30.95
# PERCENTAGE OF COMPLEX WORDS: 57.03422053231939
# FOG INDEX: 35.19368821292775
# AVG NUMBER OF WORDS PER SENTENCE: 30.95
# COMPLEX WORD COUNT: 150
# WORD COUNT: 263
# SYLLABLE PER WORD: 2.376425855513308
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.106463878326996
# POLARITY SCORE (Custom): 0.7692307396449716
# SUBJECTIVITY SCORE (Custom): 0.09885931521346268
# POLARITY SCORE (TextBlob): 0.0913095238095238
# SUBJECTIVITY SCORE (TextBlob): 0.5600793650793651
# -----------------------
# Extracted and saved: extracted_texts/blackassign0025.txt
# URL_ID: blackassign0025
# URL: https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/
# AVG SENTENCE LENGTH: 46.0
# PERCENTAGE OF COMPLEX WORDS: 47.05882352941176
# FOG INDEX: 37.22352941176471
# AVG NUMBER OF WORDS PER SENTENCE: 46.0
# COMPLEX WORD COUNT: 200
# WORD COUNT: 425
# SYLLABLE PER WORD: 2.12
# PERSONAL PRONOUNS: 14
# AVG WORD LENGTH: 6.550588235294118
# POLARITY SCORE (Custom): 0.26666665777777804
# SUBJECTIVITY SCORE (Custom): 0.07058823512802768
# POLARITY SCORE (TextBlob): 0.07579020013802623
# SUBJECTIVITY SCORE (TextBlob): 0.43256038647342987
# -----------------------
# Extracted and saved: extracted_texts/blackassign0026.txt
# URL_ID: blackassign0026
# URL: https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/
# AVG SENTENCE LENGTH: 24.975
# PERCENTAGE OF COMPLEX WORDS: 55.25114155251142
# FOG INDEX: 32.09045662100457
# AVG NUMBER OF WORDS PER SENTENCE: 24.975
# COMPLEX WORD COUNT: 242
# WORD COUNT: 438
# SYLLABLE PER WORD: 2.324200913242009
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 7.018264840182648
# POLARITY SCORE (Custom): 0.24324323666910172
# SUBJECTIVITY SCORE (Custom): 0.08447488565188382
# POLARITY SCORE (TextBlob): 0.13522418058132343
# SUBJECTIVITY SCORE (TextBlob): 0.42674242424242426
# -----------------------
# Extracted and saved: extracted_texts/blackassign0027.txt
# URL_ID: blackassign0027
# URL: https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/
# AVG SENTENCE LENGTH: 28.096153846153847
# PERCENTAGE OF COMPLEX WORDS: 47.408829174664106
# FOG INDEX: 30.20199320832718
# AVG NUMBER OF WORDS PER SENTENCE: 28.096153846153847
# COMPLEX WORD COUNT: 247
# WORD COUNT: 521
# SYLLABLE PER WORD: 2.1573896353166986
# PERSONAL PRONOUNS: 32
# AVG WORD LENGTH: 6.596928982725528
# POLARITY SCORE (Custom): -0.03999999920000002
# SUBJECTIVITY SCORE (Custom): 0.0959692896430532
# POLARITY SCORE (TextBlob): 0.09198756747367857
# SUBJECTIVITY SCORE (TextBlob): 0.45257953466286777
# -----------------------
# Extracted and saved: extracted_texts/blackassign0028.txt
# URL_ID: blackassign0028
# URL: https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/
# AVG SENTENCE LENGTH: 32.63157894736842
# PERCENTAGE OF COMPLEX WORDS: 61.86612576064908
# FOG INDEX: 37.799081883207
# AVG NUMBER OF WORDS PER SENTENCE: 32.63157894736842
# COMPLEX WORD COUNT: 305
# WORD COUNT: 493
# SYLLABLE PER WORD: 2.365111561866126
# PERSONAL PRONOUNS: 17
# AVG WORD LENGTH: 7.494929006085193
# POLARITY SCORE (Custom): 0.12280701538935061
# SUBJECTIVITY SCORE (Custom): 0.11561866102308588
# POLARITY SCORE (TextBlob): 0.10363295654962323
# SUBJECTIVITY SCORE (TextBlob): 0.4291121532788199
# -----------------------
# Extracted and saved: extracted_texts/blackassign0029.txt
# URL_ID: blackassign0029
# URL: https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/
# AVG SENTENCE LENGTH: 26.546666666666667
# PERCENTAGE OF COMPLEX WORDS: 64.11042944785275
# FOG INDEX: 36.262838445807766
# AVG NUMBER OF WORDS PER SENTENCE: 26.546666666666667
# COMPLEX WORD COUNT: 627
# WORD COUNT: 978
# SYLLABLE PER WORD: 2.4151329243353783
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 7.381390593047035
# POLARITY SCORE (Custom): 0.3199999968
# SUBJECTIVITY SCORE (Custom): 0.10224948864800666
# POLARITY SCORE (TextBlob): 0.13693643937761585
# SUBJECTIVITY SCORE (TextBlob): 0.46336424033482865
# -----------------------
# Extracted and saved: extracted_texts/blackassign0030.txt
# URL_ID: blackassign0030
# URL: https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/
# AVG SENTENCE LENGTH: 20.620253164556964
# PERCENTAGE OF COMPLEX WORDS: 50.170648464163826
# FOG INDEX: 28.316360651488317
# AVG NUMBER OF WORDS PER SENTENCE: 20.620253164556964
# COMPLEX WORD COUNT: 294
# WORD COUNT: 586
# SYLLABLE PER WORD: 2.196245733788396
# PERSONAL PRONOUNS: 10
# AVG WORD LENGTH: 6.812286689419795
# POLARITY SCORE (Custom): 0.23711339961738764
# SUBJECTIVITY SCORE (Custom): 0.16552900995643513
# POLARITY SCORE (TextBlob): 0.07469251007613077
# SUBJECTIVITY SCORE (TextBlob): 0.43359613375130607
# -----------------------
# Extracted and saved: extracted_texts/blackassign0031.txt
# URL_ID: blackassign0031
# URL: https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/
# AVG SENTENCE LENGTH: 22.607142857142858
# PERCENTAGE OF COMPLEX WORDS: 65.68742655699178
# FOG INDEX: 35.31782776565386
# AVG NUMBER OF WORDS PER SENTENCE: 22.607142857142858
# COMPLEX WORD COUNT: 559
# WORD COUNT: 851
# SYLLABLE PER WORD: 2.4582843713278497
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 7.508813160987074
# POLARITY SCORE (Custom): 0.2871287100284286
# SUBJECTIVITY SCORE (Custom): 0.1186839011531329
# POLARITY SCORE (TextBlob): 0.11268935609844702
# SUBJECTIVITY SCORE (TextBlob): 0.488862122725759
# -----------------------
# Extracted and saved: extracted_texts/blackassign0032.txt
# URL_ID: blackassign0032
# URL: https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/
# AVG SENTENCE LENGTH: 19.384615384615383
# PERCENTAGE OF COMPLEX WORDS: 50.75301204819277
# FOG INDEX: 28.055050973123265
# AVG NUMBER OF WORDS PER SENTENCE: 19.384615384615383
# COMPLEX WORD COUNT: 337
# WORD COUNT: 664
# SYLLABLE PER WORD: 2.1822289156626504
# PERSONAL PRONOUNS: 24
# AVG WORD LENGTH: 6.754518072289157
# POLARITY SCORE (Custom): 0.3999999955555556
# SUBJECTIVITY SCORE (Custom): 0.13554216847056902
# POLARITY SCORE (TextBlob): 0.14641465951306376
# SUBJECTIVITY SCORE (TextBlob): 0.5008115156120474
# -----------------------
# Extracted and saved: extracted_texts/blackassign0033.txt
# URL_ID: blackassign0033
# URL: https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/
# AVG SENTENCE LENGTH: 25.31578947368421
# PERCENTAGE OF COMPLEX WORDS: 55.702917771883286
# FOG INDEX: 32.407482898227
# AVG NUMBER OF WORDS PER SENTENCE: 25.31578947368421
# COMPLEX WORD COUNT: 420
# WORD COUNT: 754
# SYLLABLE PER WORD: 2.310344827586207
# PERSONAL PRONOUNS: 19
# AVG WORD LENGTH: 7.140583554376658
# POLARITY SCORE (Custom): 0.4249999946875001
# SUBJECTIVITY SCORE (Custom): 0.10610079561525093
# POLARITY SCORE (TextBlob): 0.05467606111836885
# SUBJECTIVITY SCORE (TextBlob): 0.5109679226099346
# -----------------------
# Extracted and saved: extracted_texts/blackassign0034.txt
# URL_ID: blackassign0034
# URL: https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/
# AVG SENTENCE LENGTH: 25.654545454545456
# PERCENTAGE OF COMPLEX WORDS: 54.76635514018692
# FOG INDEX: 32.16836023789295
# AVG NUMBER OF WORDS PER SENTENCE: 25.654545454545456
# COMPLEX WORD COUNT: 293
# WORD COUNT: 535
# SYLLABLE PER WORD: 2.2616822429906542
# PERSONAL PRONOUNS: 36
# AVG WORD LENGTH: 7.046728971962617
# POLARITY SCORE (Custom): 0.3134328311427936
# SUBJECTIVITY SCORE (Custom): 0.1252336446257315
# POLARITY SCORE (TextBlob): 0.11950362792343922
# SUBJECTIVITY SCORE (TextBlob): 0.45930167578752484
# -----------------------
# Extracted and saved: extracted_texts/blackassign0035.txt
# URL_ID: blackassign0035
# URL: https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/
# AVG SENTENCE LENGTH: 18.863636363636363
# PERCENTAGE OF COMPLEX WORDS: 53.63636363636364
# FOG INDEX: 29.0
# AVG NUMBER OF WORDS PER SENTENCE: 18.863636363636363
# COMPLEX WORD COUNT: 177
# WORD COUNT: 330
# SYLLABLE PER WORD: 2.224242424242424
# PERSONAL PRONOUNS: 11
# AVG WORD LENGTH: 6.975757575757576
# POLARITY SCORE (Custom): 0.36842104293628836
# SUBJECTIVITY SCORE (Custom): 0.11515151480257117
# POLARITY SCORE (TextBlob): 0.1491084283363695
# SUBJECTIVITY SCORE (TextBlob): 0.4230386035533094
# -----------------------
# Failed to retrieve https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/. Status code: 404
# Extracted and saved: extracted_texts/blackassign0037.txt
# URL_ID: blackassign0037
# URL: https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/
# AVG SENTENCE LENGTH: 22.571428571428573
# PERCENTAGE OF COMPLEX WORDS: 54.662379421221864
# FOG INDEX: 30.893523197060176
# AVG NUMBER OF WORDS PER SENTENCE: 22.571428571428573
# COMPLEX WORD COUNT: 170
# WORD COUNT: 311
# SYLLABLE PER WORD: 2.032154340836013
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 6.681672025723473
# POLARITY SCORE (Custom): 0.49019606881968497
# SUBJECTIVITY SCORE (Custom): 0.16398713773637577
# POLARITY SCORE (TextBlob): 0.1933409660514924
# SUBJECTIVITY SCORE (TextBlob): 0.5740308726361358
# -----------------------
# Extracted and saved: extracted_texts/blackassign0038.txt
# URL_ID: blackassign0038
# URL: https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/
# AVG SENTENCE LENGTH: 30.0625
# PERCENTAGE OF COMPLEX WORDS: 53.04621848739496
# FOG INDEX: 33.24348739495798
# AVG NUMBER OF WORDS PER SENTENCE: 30.0625
# COMPLEX WORD COUNT: 505
# WORD COUNT: 952
# SYLLABLE PER WORD: 2.2605042016806722
# PERSONAL PRONOUNS: 12
# AVG WORD LENGTH: 6.850840336134453
# POLARITY SCORE (Custom): 0.24074073851165984
# SUBJECTIVITY SCORE (Custom): 0.11344537803209519
# POLARITY SCORE (TextBlob): 0.1685887445887446
# SUBJECTIVITY SCORE (TextBlob): 0.5311564854898188
# -----------------------
# Extracted and saved: extracted_texts/blackassign0039.txt
# URL_ID: blackassign0039
# URL: https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/
# AVG SENTENCE LENGTH: 24.7
# PERCENTAGE OF COMPLEX WORDS: 56.54627539503386
# FOG INDEX: 32.498510158013545
# AVG NUMBER OF WORDS PER SENTENCE: 24.7
# COMPLEX WORD COUNT: 501
# WORD COUNT: 886
# SYLLABLE PER WORD: 2.2471783295711063
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 6.917607223476298
# POLARITY SCORE (Custom): -0.16666666512345682
# SUBJECTIVITY SCORE (Custom): 0.12189616239063639
# POLARITY SCORE (TextBlob): 0.12084157564290018
# SUBJECTIVITY SCORE (TextBlob): 0.4682307023366626
# -----------------------
# Extracted and saved: extracted_texts/blackassign0040.txt
# URL_ID: blackassign0040
# URL: https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/
# AVG SENTENCE LENGTH: 22.56140350877193
# PERCENTAGE OF COMPLEX WORDS: 66.43835616438356
# FOG INDEX: 35.5999038692622
# AVG NUMBER OF WORDS PER SENTENCE: 22.56140350877193
# COMPLEX WORD COUNT: 388
# WORD COUNT: 584
# SYLLABLE PER WORD: 2.4434931506849313
# PERSONAL PRONOUNS: 11
# AVG WORD LENGTH: 7.537671232876712
# POLARITY SCORE (Custom): 0.2280701714373654
# SUBJECTIVITY SCORE (Custom): 0.09760273955889942
# POLARITY SCORE (TextBlob): 0.11639375561545375
# SUBJECTIVITY SCORE (TextBlob): 0.41973403169157875
# -----------------------
# Extracted and saved: extracted_texts/blackassign0041.txt
# URL_ID: blackassign0041
# URL: https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/
# AVG SENTENCE LENGTH: 17.5
# PERCENTAGE OF COMPLEX WORDS: 50.86206896551724
# FOG INDEX: 27.344827586206897
# AVG NUMBER OF WORDS PER SENTENCE: 17.5
# COMPLEX WORD COUNT: 295
# WORD COUNT: 580
# SYLLABLE PER WORD: 2.2344827586206897
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 6.789655172413793
# POLARITY SCORE (Custom): 0.03333333277777779
# SUBJECTIVITY SCORE (Custom): 0.10344827568370987
# POLARITY SCORE (TextBlob): 0.10607930070203922
# SUBJECTIVITY SCORE (TextBlob): 0.3785477329687856
# -----------------------
# Extracted and saved: extracted_texts/blackassign0042.txt
# URL_ID: blackassign0042
# URL: https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/
# AVG SENTENCE LENGTH: 29.783333333333335
# PERCENTAGE OF COMPLEX WORDS: 53.96825396825397
# FOG INDEX: 33.50063492063492
# AVG NUMBER OF WORDS PER SENTENCE: 29.783333333333335
# COMPLEX WORD COUNT: 340
# WORD COUNT: 630
# SYLLABLE PER WORD: 2.3190476190476192
# PERSONAL PRONOUNS: 34
# AVG WORD LENGTH: 7.158730158730159
# POLARITY SCORE (Custom): 0.4285714234693878
# SUBJECTIVITY SCORE (Custom): 0.13333333312169313
# POLARITY SCORE (TextBlob): 0.1610503569278404
# SUBJECTIVITY SCORE (TextBlob): 0.3904880880708694
# -----------------------
# Extracted and saved: extracted_texts/blackassign0043.txt
# URL_ID: blackassign0043
# URL: https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/
# AVG SENTENCE LENGTH: 21.9
# PERCENTAGE OF COMPLEX WORDS: 56.17977528089888
# FOG INDEX: 31.23191011235955
# AVG NUMBER OF WORDS PER SENTENCE: 21.9
# COMPLEX WORD COUNT: 400
# WORD COUNT: 712
# SYLLABLE PER WORD: 2.287921348314607
# PERSONAL PRONOUNS: 15
# AVG WORD LENGTH: 7.007022471910112
# POLARITY SCORE (Custom): 0.4999999943181819
# SUBJECTIVITY SCORE (Custom): 0.12359550544438834
# POLARITY SCORE (TextBlob): 0.05924606107532938
# SUBJECTIVITY SCORE (TextBlob): 0.46846029986273896
# -----------------------
# Extracted and saved: extracted_texts/blackassign0044.txt
# URL_ID: blackassign0044
# URL: https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/
# AVG SENTENCE LENGTH: 26.571428571428573
# PERCENTAGE OF COMPLEX WORDS: 60.3921568627451
# FOG INDEX: 34.785434173669465
# AVG NUMBER OF WORDS PER SENTENCE: 26.571428571428573
# COMPLEX WORD COUNT: 154
# WORD COUNT: 255
# SYLLABLE PER WORD: 2.384313725490196
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 7.407843137254902
# POLARITY SCORE (Custom): 0.9999999615384629
# SUBJECTIVITY SCORE (Custom): 0.10196078391387928
# POLARITY SCORE (TextBlob): 0.1761308203991131
# SUBJECTIVITY SCORE (TextBlob): 0.5311677753141167
# -----------------------
# Extracted and saved: extracted_texts/blackassign0045.txt
# URL_ID: blackassign0045
# URL: https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/
# AVG SENTENCE LENGTH: 235.125
# PERCENTAGE OF COMPLEX WORDS: 51.68067226890757
# FOG INDEX: 114.72226890756303
# AVG NUMBER OF WORDS PER SENTENCE: 235.125
# COMPLEX WORD COUNT: 369
# WORD COUNT: 714
# SYLLABLE PER WORD: 2.208683473389356
# PERSONAL PRONOUNS: 19
# AVG WORD LENGTH: 6.899159663865547
# POLARITY SCORE (Custom): 0.33898304797471995
# SUBJECTIVITY SCORE (Custom): 0.1652661062111119
# POLARITY SCORE (TextBlob): 0.1326305759457933
# SUBJECTIVITY SCORE (TextBlob): 0.504171019198193
# -----------------------
# Extracted and saved: extracted_texts/blackassign0046.txt
# URL_ID: blackassign0046
# URL: https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/
# AVG SENTENCE LENGTH: 18.711111111111112
# PERCENTAGE OF COMPLEX WORDS: 57.83475783475783
# FOG INDEX: 30.61834757834758
# AVG NUMBER OF WORDS PER SENTENCE: 18.711111111111112
# COMPLEX WORD COUNT: 203
# WORD COUNT: 351
# SYLLABLE PER WORD: 2.3276353276353277
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.062678062678063
# POLARITY SCORE (Custom): 0.9999999500000024
# SUBJECTIVITY SCORE (Custom): 0.056980056817720635
# POLARITY SCORE (TextBlob): 0.22415371513732166
# SUBJECTIVITY SCORE (TextBlob): 0.4207348662266695
# -----------------------
# Extracted and saved: extracted_texts/blackassign0047.txt
# URL_ID: blackassign0047
# URL: https://insights.blackcoffer.com/evolution-of-advertising-industry/
# AVG SENTENCE LENGTH: 20.075
# PERCENTAGE OF COMPLEX WORDS: 66.189111747851
# FOG INDEX: 34.505644699140404
# AVG NUMBER OF WORDS PER SENTENCE: 20.075
# COMPLEX WORD COUNT: 231
# WORD COUNT: 349
# SYLLABLE PER WORD: 2.567335243553009
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.724928366762177
# POLARITY SCORE (Custom): 0.399999980000001
# SUBJECTIVITY SCORE (Custom): 0.05730659009367739
# POLARITY SCORE (TextBlob): 0.0876316738816739
# SUBJECTIVITY SCORE (TextBlob): 0.34342171717171716
# -----------------------
# Extracted and saved: extracted_texts/blackassign0048.txt
# URL_ID: blackassign0048
# URL: https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/
# AVG SENTENCE LENGTH: 32.0
# PERCENTAGE OF COMPLEX WORDS: 60.86956521739131
# FOG INDEX: 37.14782608695653
# AVG NUMBER OF WORDS PER SENTENCE: 32.0
# COMPLEX WORD COUNT: 42
# WORD COUNT: 69
# SYLLABLE PER WORD: 2.4927536231884058
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 7.202898550724638
# POLARITY SCORE (Custom): -0.9999996666667778
# SUBJECTIVITY SCORE (Custom): 0.0434782602394455
# POLARITY SCORE (TextBlob): 0.11356437679967092
# SUBJECTIVITY SCORE (TextBlob): 0.36173042643630876
# -----------------------
# Failed to retrieve https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/. Status code: 404
# Extracted and saved: extracted_texts/blackassign0050.txt
# URL_ID: blackassign0050
# URL: https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/
# AVG SENTENCE LENGTH: 27.581818181818182
# PERCENTAGE OF COMPLEX WORDS: 55.53822152886115
# FOG INDEX: 33.24801588427174
# AVG NUMBER OF WORDS PER SENTENCE: 27.581818181818182
# COMPLEX WORD COUNT: 356
# WORD COUNT: 641
# SYLLABLE PER WORD: 2.2386895475819033
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 7.048361934477379
# POLARITY SCORE (Custom): -0.47826086436672977
# SUBJECTIVITY SCORE (Custom): 0.14352574080573208
# POLARITY SCORE (TextBlob): 0.0441591080876795
# SUBJECTIVITY SCORE (TextBlob): 0.3958860980289551
# -----------------------
# Extracted and saved: extracted_texts/blackassign0051.txt
# URL_ID: blackassign0051
# URL: https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/
# AVG SENTENCE LENGTH: 28.321428571428573
# PERCENTAGE OF COMPLEX WORDS: 56.00000000000001
# FOG INDEX: 33.728571428571435
# AVG NUMBER OF WORDS PER SENTENCE: 28.321428571428573
# COMPLEX WORD COUNT: 182
# WORD COUNT: 325
# SYLLABLE PER WORD: 2.276923076923077
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 6.892307692307693
# POLARITY SCORE (Custom): 0.09677419042663901
# SUBJECTIVITY SCORE (Custom): 0.09538461509112427
# POLARITY SCORE (TextBlob): 0.15593822843822838
# SUBJECTIVITY SCORE (TextBlob): 0.4100283050283051
# -----------------------
# Extracted and saved: extracted_texts/blackassign0052.txt
# URL_ID: blackassign0052
# URL: https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/
# AVG SENTENCE LENGTH: 19.46788990825688
# PERCENTAGE OF COMPLEX WORDS: 54.31145431145431
# FOG INDEX: 29.511737687884477
# AVG NUMBER OF WORDS PER SENTENCE: 19.46788990825688
# COMPLEX WORD COUNT: 422
# WORD COUNT: 777
# SYLLABLE PER WORD: 2.277992277992278
# PERSONAL PRONOUNS: 15
# AVG WORD LENGTH: 6.985842985842986
# POLARITY SCORE (Custom): 0.2127659551833409
# SUBJECTIVITY SCORE (Custom): 0.12097812082242199
# POLARITY SCORE (TextBlob): 0.19692985525472845
# SUBJECTIVITY SCORE (TextBlob): 0.4750393599632181
# -----------------------
# Extracted and saved: extracted_texts/blackassign0053.txt
# URL_ID: blackassign0053
# URL: https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/
# AVG SENTENCE LENGTH: 17.046511627906977
# PERCENTAGE OF COMPLEX WORDS: 56.47840531561462
# FOG INDEX: 29.40996677740864
# AVG NUMBER OF WORDS PER SENTENCE: 17.046511627906977
# COMPLEX WORD COUNT: 170
# WORD COUNT: 301
# SYLLABLE PER WORD: 2.4119601328903655
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 7.239202657807309
# POLARITY SCORE (Custom): 0.8604650962682536
# SUBJECTIVITY SCORE (Custom): 0.1428571423825344
# POLARITY SCORE (TextBlob): 0.27188644688644686
# SUBJECTIVITY SCORE (TextBlob): 0.5027521367521367
# -----------------------
# Extracted and saved: extracted_texts/blackassign0054.txt
# URL_ID: blackassign0054
# URL: https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/
# AVG SENTENCE LENGTH: 25.375
# PERCENTAGE OF COMPLEX WORDS: 38.333333333333336
# FOG INDEX: 25.483333333333334
# AVG NUMBER OF WORDS PER SENTENCE: 25.375
# COMPLEX WORD COUNT: 69
# WORD COUNT: 180
# SYLLABLE PER WORD: 2.0444444444444443
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 6.4944444444444445
# POLARITY SCORE (Custom): 0.599999880000024
# SUBJECTIVITY SCORE (Custom): 0.02777777762345679
# POLARITY SCORE (TextBlob): 0.12852891156462584
# SUBJECTIVITY SCORE (TextBlob): 0.43758503401360543
# -----------------------
# Extracted and saved: extracted_texts/blackassign0055.txt
# URL_ID: blackassign0055
# URL: https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/
# AVG SENTENCE LENGTH: 26.558823529411764
# PERCENTAGE OF COMPLEX WORDS: 41.23989218328841
# FOG INDEX: 27.11948628508007
# AVG NUMBER OF WORDS PER SENTENCE: 26.558823529411764
# COMPLEX WORD COUNT: 153
# WORD COUNT: 371
# SYLLABLE PER WORD: 2.0646900269541777
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 6.420485175202156
# POLARITY SCORE (Custom): 0.4838709521331951
# SUBJECTIVITY SCORE (Custom): 0.0835579512572562
# POLARITY SCORE (TextBlob): 0.16673505892255894
# SUBJECTIVITY SCORE (TextBlob): 0.47165404040404035
# -----------------------
# Extracted and saved: extracted_texts/blackassign0056.txt
# URL_ID: blackassign0056
# URL: https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/
# AVG SENTENCE LENGTH: 27.94736842105263
# PERCENTAGE OF COMPLEX WORDS: 55.88235294117647
# FOG INDEX: 33.531888544891636
# AVG NUMBER OF WORDS PER SENTENCE: 27.94736842105263
# COMPLEX WORD COUNT: 133
# WORD COUNT: 238
# SYLLABLE PER WORD: 2.310924369747899
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 6.9411764705882355
# POLARITY SCORE (Custom): 0.23809522675737013
# SUBJECTIVITY SCORE (Custom): 0.08823529374691053
# POLARITY SCORE (TextBlob): 0.11930214846881515
# SUBJECTIVITY SCORE (TextBlob): 0.3954986371653039
# -----------------------
# Extracted and saved: extracted_texts/blackassign0057.txt
# URL_ID: blackassign0057
# URL: https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/
# AVG SENTENCE LENGTH: 15.777777777777779
# PERCENTAGE OF COMPLEX WORDS: 63.33333333333333
# FOG INDEX: 31.644444444444446
# AVG NUMBER OF WORDS PER SENTENCE: 15.777777777777779
# COMPLEX WORD COUNT: 95
# WORD COUNT: 150
# SYLLABLE PER WORD: 2.506666666666667
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 7.726666666666667
# POLARITY SCORE (Custom): 0.3043478128544429
# SUBJECTIVITY SCORE (Custom): 0.15333333231111113
# POLARITY SCORE (TextBlob): 0.22744949494949493
# SUBJECTIVITY SCORE (TextBlob): 0.5095454545454545
# -----------------------
# Extracted and saved: extracted_texts/blackassign0058.txt
# URL_ID: blackassign0058
# URL: https://insights.blackcoffer.com/how-we-forecast-future-technologies/
# AVG SENTENCE LENGTH: 16.9
# PERCENTAGE OF COMPLEX WORDS: 56.79012345679012
# FOG INDEX: 29.47604938271605
# AVG NUMBER OF WORDS PER SENTENCE: 16.9
# COMPLEX WORD COUNT: 46
# WORD COUNT: 81
# SYLLABLE PER WORD: 2.493827160493827
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 7.54320987654321
# POLARITY SCORE (Custom): 0.99999980000004
# SUBJECTIVITY SCORE (Custom): 0.06172839429964946
# POLARITY SCORE (TextBlob): 0.04611801242236026
# SUBJECTIVITY SCORE (TextBlob): 0.2803312629399586
# -----------------------
# Extracted and saved: extracted_texts/blackassign0059.txt
# URL_ID: blackassign0059
# URL: https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/
# AVG SENTENCE LENGTH: 17.072727272727274
# PERCENTAGE OF COMPLEX WORDS: 44.61538461538462
# FOG INDEX: 24.67524475524476
# AVG NUMBER OF WORDS PER SENTENCE: 17.072727272727274
# COMPLEX WORD COUNT: 145
# WORD COUNT: 325
# SYLLABLE PER WORD: 2.1015384615384614
# PERSONAL PRONOUNS: 31
# AVG WORD LENGTH: 6.584615384615384
# POLARITY SCORE (Custom): -0.24137930618311543
# SUBJECTIVITY SCORE (Custom): 0.17846153791242603
# POLARITY SCORE (TextBlob): 0.05008615288220553
# SUBJECTIVITY SCORE (TextBlob): 0.48135964912280715
# -----------------------
# Extracted and saved: extracted_texts/blackassign0060.txt
# URL_ID: blackassign0060
# URL: https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/
# AVG SENTENCE LENGTH: 21.666666666666668
# PERCENTAGE OF COMPLEX WORDS: 50.0
# FOG INDEX: 28.66666666666667
# AVG NUMBER OF WORDS PER SENTENCE: 21.666666666666668
# COMPLEX WORD COUNT: 37
# WORD COUNT: 74
# SYLLABLE PER WORD: 2.0945945945945947
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 6.527027027027027
# POLARITY SCORE (Custom): 0.636363578512402
# SUBJECTIVITY SCORE (Custom): 0.14864864663988317
# POLARITY SCORE (TextBlob): 0.3378571428571428
# SUBJECTIVITY SCORE (TextBlob): 0.45642857142857146
# -----------------------
# Extracted and saved: extracted_texts/blackassign0061.txt
# URL_ID: blackassign0061
# URL: https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/
# AVG SENTENCE LENGTH: 24.29032258064516
# PERCENTAGE OF COMPLEX WORDS: 64.17910447761194
# FOG INDEX: 35.387770823302844
# AVG NUMBER OF WORDS PER SENTENCE: 24.29032258064516
# COMPLEX WORD COUNT: 215
# WORD COUNT: 335
# SYLLABLE PER WORD: 2.4417910447761195
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 7.632835820895522
# POLARITY SCORE (Custom): 0.4999999886363639
# SUBJECTIVITY SCORE (Custom): 0.13134328319002006
# POLARITY SCORE (TextBlob): 0.07827708907254362
# SUBJECTIVITY SCORE (TextBlob): 0.40386822773186404
# -----------------------
# Extracted and saved: extracted_texts/blackassign0062.txt
# URL_ID: blackassign0062
# URL: https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/
# AVG SENTENCE LENGTH: 31.8
# PERCENTAGE OF COMPLEX WORDS: 44.44444444444444
# FOG INDEX: 30.497777777777777
# AVG NUMBER OF WORDS PER SENTENCE: 31.8
# COMPLEX WORD COUNT: 24
# WORD COUNT: 54
# SYLLABLE PER WORD: 2.0555555555555554
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 6.425925925925926
# POLARITY SCORE (Custom): -0.7499999062500118
# SUBJECTIVITY SCORE (Custom): 0.14814814540466398
# POLARITY SCORE (TextBlob): 0.07208273208273208
# SUBJECTIVITY SCORE (TextBlob): 0.508917748917749
# -----------------------
# Extracted and saved: extracted_texts/blackassign0063.txt
# URL_ID: blackassign0063
# URL: https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/
# AVG SENTENCE LENGTH: 19.238095238095237
# PERCENTAGE OF COMPLEX WORDS: 49.25373134328358
# FOG INDEX: 27.396730632551527
# AVG NUMBER OF WORDS PER SENTENCE: 19.238095238095237
# COMPLEX WORD COUNT: 66
# WORD COUNT: 134
# SYLLABLE PER WORD: 2.1791044776119404
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 6.798507462686567
# POLARITY SCORE (Custom): -0.47058822145328766
# SUBJECTIVITY SCORE (Custom): 0.25373134139006465
# POLARITY SCORE (TextBlob): 0.02685479129923574
# SUBJECTIVITY SCORE (TextBlob): 0.6155614344503233
# -----------------------
# Extracted and saved: extracted_texts/blackassign0064.txt
# URL_ID: blackassign0064
# URL: https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/
# AVG SENTENCE LENGTH: 26.89041095890411
# PERCENTAGE OF COMPLEX WORDS: 59.832134292565954
# FOG INDEX: 34.68901810058803
# AVG NUMBER OF WORDS PER SENTENCE: 26.89041095890411
# COMPLEX WORD COUNT: 499
# WORD COUNT: 834
# SYLLABLE PER WORD: 2.4268585131894485
# PERSONAL PRONOUNS: 21
# AVG WORD LENGTH: 7.551558752997602
# POLARITY SCORE (Custom): -0.32432431994156324
# SUBJECTIVITY SCORE (Custom): 0.08872901668018103
# POLARITY SCORE (TextBlob): 0.08833467850417004
# SUBJECTIVITY SCORE (TextBlob): 0.40406645143933273
# -----------------------
# Extracted and saved: extracted_texts/blackassign0065.txt
# URL_ID: blackassign0065
# URL: https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/
# AVG SENTENCE LENGTH: 27.852941176470587
# PERCENTAGE OF COMPLEX WORDS: 47.752808988764045
# FOG INDEX: 30.242300066093858
# AVG NUMBER OF WORDS PER SENTENCE: 27.852941176470587
# COMPLEX WORD COUNT: 340
# WORD COUNT: 712
# SYLLABLE PER WORD: 2.162921348314607
# PERSONAL PRONOUNS: 21
# AVG WORD LENGTH: 6.771067415730337
# POLARITY SCORE (Custom): 0.32307691810650896
# SUBJECTIVITY SCORE (Custom): 0.09129213470324138
# POLARITY SCORE (TextBlob): 0.12424151623131215
# SUBJECTIVITY SCORE (TextBlob): 0.5002988621355966
# -----------------------
# Extracted and saved: extracted_texts/blackassign0066.txt
# URL_ID: blackassign0066
# URL: https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/
# AVG SENTENCE LENGTH: 20.506172839506174
# PERCENTAGE OF COMPLEX WORDS: 48.055987558320375
# FOG INDEX: 27.42486415913062
# AVG NUMBER OF WORDS PER SENTENCE: 20.506172839506174
# COMPLEX WORD COUNT: 309
# WORD COUNT: 643
# SYLLABLE PER WORD: 2.1493001555209954
# PERSONAL PRONOUNS: 33
# AVG WORD LENGTH: 6.640746500777605
# POLARITY SCORE (Custom): 0.15254237029589204
# SUBJECTIVITY SCORE (Custom): 0.09175738710457639
# POLARITY SCORE (TextBlob): 0.06454872646733112
# SUBJECTIVITY SCORE (TextBlob): 0.398343484680694
# -----------------------
# Extracted and saved: extracted_texts/blackassign0067.txt
# URL_ID: blackassign0067
# URL: https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot/
# AVG SENTENCE LENGTH: 15.80327868852459
# PERCENTAGE OF COMPLEX WORDS: 59.150326797385624
# FOG INDEX: 29.98144219436409
# AVG NUMBER OF WORDS PER SENTENCE: 15.80327868852459
# COMPLEX WORD COUNT: 181
# WORD COUNT: 306
# SYLLABLE PER WORD: 2.2941176470588234
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.016339869281046
# POLARITY SCORE (Custom): 0.5483870790842877
# SUBJECTIVITY SCORE (Custom): 0.10130718921141442
# POLARITY SCORE (TextBlob): 0.18021978021978025
# SUBJECTIVITY SCORE (TextBlob): 0.4836742744435053
# -----------------------
# Extracted and saved: extracted_texts/blackassign0068.txt
# URL_ID: blackassign0068
# URL: https://insights.blackcoffer.com/how-you-lead-a-project-or-a-team-without-any-technical-expertise/
# AVG SENTENCE LENGTH: 24.676923076923078
# PERCENTAGE OF COMPLEX WORDS: 53.55731225296443
# FOG INDEX: 31.293694131955007
# AVG NUMBER OF WORDS PER SENTENCE: 24.676923076923078
# COMPLEX WORD COUNT: 271
# WORD COUNT: 506
# SYLLABLE PER WORD: 2.150197628458498
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 6.91699604743083
# POLARITY SCORE (Custom): 0.6734693740108292
# SUBJECTIVITY SCORE (Custom): 0.09683794447265229
# POLARITY SCORE (TextBlob): 0.2201765188834155
# SUBJECTIVITY SCORE (TextBlob): 0.43684318555008217
# -----------------------
# Extracted and saved: extracted_texts/blackassign0069.txt
# URL_ID: blackassign0069
# URL: https://insights.blackcoffer.com/can-you-be-great-leader-without-technical-expertise/
# AVG SENTENCE LENGTH: 32.4375
# PERCENTAGE OF COMPLEX WORDS: 52.352941176470594
# FOG INDEX: 33.91617647058824
# AVG NUMBER OF WORDS PER SENTENCE: 32.4375
# COMPLEX WORD COUNT: 89
# WORD COUNT: 170
# SYLLABLE PER WORD: 2.2941176470588234
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 7.064705882352941
# POLARITY SCORE (Custom): 0.6666666481481487
# SUBJECTIVITY SCORE (Custom): 0.2117647046366782
# POLARITY SCORE (TextBlob): 0.25395622895622894
# SUBJECTIVITY SCORE (TextBlob): 0.5148629148629151
# -----------------------
# Extracted and saved: extracted_texts/blackassign0070.txt
# URL_ID: blackassign0070
# URL: https://insights.blackcoffer.com/how-does-artificial-intelligence-affect-the-environment/
# AVG SENTENCE LENGTH: 25.884057971014492
# PERCENTAGE OF COMPLEX WORDS: 55.467720685111985
# FOG INDEX: 32.54071146245059
# AVG NUMBER OF WORDS PER SENTENCE: 25.884057971014492
# COMPLEX WORD COUNT: 421
# WORD COUNT: 759
# SYLLABLE PER WORD: 2.3069828722002637
# PERSONAL PRONOUNS: 9
# AVG WORD LENGTH: 7.054018445322793
# POLARITY SCORE (Custom): 0.41818181057851256
# SUBJECTIVITY SCORE (Custom): 0.07246376802046935
# POLARITY SCORE (TextBlob): 0.12155610912076428
# SUBJECTIVITY SCORE (TextBlob): 0.453966608104539
# -----------------------
# Extracted and saved: extracted_texts/blackassign0071.txt
# URL_ID: blackassign0071
# URL: https://insights.blackcoffer.com/how-to-overcome-your-fear-of-making-mistakes-2/
# AVG SENTENCE LENGTH: 15.078947368421053
# PERCENTAGE OF COMPLEX WORDS: 51.85185185185185
# FOG INDEX: 26.772319688109164
# AVG NUMBER OF WORDS PER SENTENCE: 15.078947368421053
# COMPLEX WORD COUNT: 196
# WORD COUNT: 378
# SYLLABLE PER WORD: 2.1693121693121693
# PERSONAL PRONOUNS: 17
# AVG WORD LENGTH: 6.775132275132275
# POLARITY SCORE (Custom): -0.5106382924400181
# SUBJECTIVITY SCORE (Custom): 0.24867724801937235
# POLARITY SCORE (TextBlob): 0.07966044837178857
# SUBJECTIVITY SCORE (TextBlob): 0.5755105547373589
# -----------------------
# Extracted and saved: extracted_texts/blackassign0072.txt
# ...
# POLARITY SCORE (TextBlob): 0.01403318903318903
# SUBJECTIVITY SCORE (TextBlob): 0.3781537906537907
# -----------------------
# Extracted and saved: extracted_texts/blackassign0078.txt
# URL_ID: blackassign0078
# URL: https://insights.blackcoffer.com/impacts-of-covid-19-on-vegetable-vendors/
# AVG SENTENCE LENGTH: 33.916666666666664
# PERCENTAGE OF COMPLEX WORDS: 54.41988950276243
# FOG INDEX: 35.33462246777164
# AVG NUMBER OF WORDS PER SENTENCE: 33.916666666666664
# COMPLEX WORD COUNT: 197
# WORD COUNT: 362
# SYLLABLE PER WORD: 2.270718232044199
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 7.077348066298343
# POLARITY SCORE (Custom): 0.1428571394557824
# SUBJECTIVITY SCORE (Custom): 0.11602209912701078
# POLARITY SCORE (TextBlob): 0.09284344347635483
# SUBJECTIVITY SCORE (TextBlob): 0.38957582501886306
# -----------------------
# Extracted and saved: extracted_texts/blackassign0079.txt
# URL_ID: blackassign0079
# URL: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-tourism-aviation-industries/
# AVG SENTENCE LENGTH: 24.482142857142858
# PERCENTAGE OF COMPLEX WORDS: 54.79704797047971
# FOG INDEX: 31.71167633104903
# AVG NUMBER OF WORDS PER SENTENCE: 24.482142857142858
# COMPLEX WORD COUNT: 297
# WORD COUNT: 542
# SYLLABLE PER WORD: 2.199261992619926
# PERSONAL PRONOUNS: 8
# AVG WORD LENGTH: 6.924354243542435
# POLARITY SCORE (Custom): -0.21568627028066137
# SUBJECTIVITY SCORE (Custom): 0.09409594078580084
# POLARITY SCORE (TextBlob): 0.05494274047465541
# SUBJECTIVITY SCORE (TextBlob): 0.4236375149673021
# -----------------------
# Extracted and saved: extracted_texts/blackassign0080.txt
# URL_ID: blackassign0080
# URL: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/
# AVG SENTENCE LENGTH: 20.432989690721648
# PERCENTAGE OF COMPLEX WORDS: 42.58943781942078
# FOG INDEX: 25.208971004056973
# AVG NUMBER OF WORDS PER SENTENCE: 20.432989690721648
# COMPLEX WORD COUNT: 750
# WORD COUNT: 1761
# SYLLABLE PER WORD: 2.0749574105621806
# PERSONAL PRONOUNS: 2
# AVG WORD LENGTH: 6.551391254968768
# POLARITY SCORE (Custom): 0.5652173790170135
# SUBJECTIVITY SCORE (Custom): 0.026121521847744734
# POLARITY SCORE (TextBlob): 0.0509375651086881
# SUBJECTIVITY SCORE (TextBlob): 0.3295961168955822
# -----------------------
# Extracted and saved: extracted_texts/blackassign0081.txt
# URL_ID: blackassign0081
# URL: https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/
# AVG SENTENCE LENGTH: 23.25609756097561
# PERCENTAGE OF COMPLEX WORDS: 55.91677503250976
# FOG INDEX: 31.669149037394153
# AVG NUMBER OF WORDS PER SENTENCE: 23.25609756097561
# COMPLEX WORD COUNT: 430
# WORD COUNT: 769
# SYLLABLE PER WORD: 2.2522756827048114
# PERSONAL PRONOUNS: 18
# AVG WORD LENGTH: 7.070221066319896
# POLARITY SCORE (Custom): -0.1529411746712803
# SUBJECTIVITY SCORE (Custom): 0.11053315980424817
# POLARITY SCORE (TextBlob): 0.024026950028662362
# SUBJECTIVITY SCORE (TextBlob): 0.4642738045820238
# -----------------------
# Extracted and saved: extracted_texts/blackassign0082.txt
# URL_ID: blackassign0082
# URL: https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/
# AVG SENTENCE LENGTH: 27.89830508474576
# PERCENTAGE OF COMPLEX WORDS: 56.95538057742782
# FOG INDEX: 33.941474264869434
# AVG NUMBER OF WORDS PER SENTENCE: 27.89830508474576
# COMPLEX WORD COUNT: 434
# WORD COUNT: 762
# SYLLABLE PER WORD: 2.44750656167979
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 7.275590551181103
# POLARITY SCORE (Custom): -0.37777777358024694
# SUBJECTIVITY SCORE (Custom): 0.11811023606547214
# POLARITY SCORE (TextBlob): 0.020758380133380133
# SUBJECTIVITY SCORE (TextBlob): 0.3719696969696968
# -----------------------
# Extracted and saved: extracted_texts/blackassign0083.txt
# URL_ID: blackassign0083
# URL: https://insights.blackcoffer.com/human-rights-outlook/
# AVG SENTENCE LENGTH: 22.714285714285715
# PERCENTAGE OF COMPLEX WORDS: 33.33333333333333
# FOG INDEX: 22.419047619047618
# AVG NUMBER OF WORDS PER SENTENCE: 22.714285714285715
# COMPLEX WORD COUNT: 17
# WORD COUNT: 51
# SYLLABLE PER WORD: 2.0784313725490198
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 6.352941176470588
# POLARITY SCORE (Custom): 0.49999987500003124
# SUBJECTIVITY SCORE (Custom): 0.0784313710111496
# POLARITY SCORE (TextBlob): 0.30720779220779215
# SUBJECTIVITY SCORE (TextBlob): 0.44985930735930735
# -----------------------
# Extracted and saved: extracted_texts/blackassign0084.txt
# URL_ID: blackassign0084
# URL: https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/
# AVG SENTENCE LENGTH: 25.973684210526315
# PERCENTAGE OF COMPLEX WORDS: 50.282485875706215
# FOG INDEX: 30.502468034493013
# AVG NUMBER OF WORDS PER SENTENCE: 25.973684210526315
# COMPLEX WORD COUNT: 178
# WORD COUNT: 354
# SYLLABLE PER WORD: 2.036723163841808
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 6.734463276836158
# POLARITY SCORE (Custom): 0.7499999765625008
# SUBJECTIVITY SCORE (Custom): 0.09039547997063424
# POLARITY SCORE (TextBlob): 0.17329454253611554
# SUBJECTIVITY SCORE (TextBlob): 0.4787386302835741
# -----------------------
# Extracted and saved: extracted_texts/blackassign0085.txt
# URL_ID: blackassign0085
# URL: https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/
# AVG SENTENCE LENGTH: 16.89075630252101
# PERCENTAGE OF COMPLEX WORDS: 57.81021897810219
# FOG INDEX: 29.88039011224928
# AVG NUMBER OF WORDS PER SENTENCE: 16.89075630252101
# COMPLEX WORD COUNT: 396
# WORD COUNT: 685
# SYLLABLE PER WORD: 2.3854014598540147
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 7.264233576642336
# POLARITY SCORE (Custom): 0.02941176427335641
# SUBJECTIVITY SCORE (Custom): 0.09927007284778092
# POLARITY SCORE (TextBlob): 0.10960267701647014
# SUBJECTIVITY SCORE (TextBlob): 0.43117604617604605
# -----------------------
# Extracted and saved: extracted_texts/blackassign0086.txt
# URL_ID: blackassign0086
# URL: https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/
# AVG SENTENCE LENGTH: 21.166666666666668
# PERCENTAGE OF COMPLEX WORDS: 53.12084993359893
# FOG INDEX: 29.715006640106242
# AVG NUMBER OF WORDS PER SENTENCE: 21.166666666666668
# COMPLEX WORD COUNT: 400
# WORD COUNT: 753
# SYLLABLE PER WORD: 2.2045152722443557
# PERSONAL PRONOUNS: 6
# AVG WORD LENGTH: 6.900398406374502
# POLARITY SCORE (Custom): 0.5588235211937718
# SUBJECTIVITY SCORE (Custom): 0.09030544476719064
# POLARITY SCORE (TextBlob): 0.16158404179488525
# SUBJECTIVITY SCORE (TextBlob): 0.4413261504225361
# -----------------------
# Extracted and saved: extracted_texts/blackassign0087.txt
# URL_ID: blackassign0087
# URL: https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/
# AVG SENTENCE LENGTH: 25.58695652173913
# PERCENTAGE OF COMPLEX WORDS: 48.78048780487805
# FOG INDEX: 29.746977730646872
# AVG NUMBER OF WORDS PER SENTENCE: 25.58695652173913
# COMPLEX WORD COUNT: 240
# WORD COUNT: 492
# SYLLABLE PER WORD: 2.136178861788618
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 6.819105691056911
# POLARITY SCORE (Custom): -0.04761904686318973
# SUBJECTIVITY SCORE (Custom): 0.12804878022754312
# POLARITY SCORE (TextBlob): 0.09475304998032269
# SUBJECTIVITY SCORE (TextBlob): 0.4424435980685981
# -----------------------
# Extracted and saved: extracted_texts/blackassign0088.txt
# URL_ID: blackassign0088
# URL: https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/
# AVG SENTENCE LENGTH: 31.516666666666666
# PERCENTAGE OF COMPLEX WORDS: 56.25
# FOG INDEX: 35.10666666666667
# AVG NUMBER OF WORDS PER SENTENCE: 31.516666666666666
# COMPLEX WORD COUNT: 459
# WORD COUNT: 816
# SYLLABLE PER WORD: 2.409313725490196
# PERSONAL PRONOUNS: 1
# AVG WORD LENGTH: 7.145833333333333
# POLARITY SCORE (Custom): -0.4915254153978743
# SUBJECTIVITY SCORE (Custom): 0.0723039214800197
# POLARITY SCORE (TextBlob): 0.02981882315215649
# SUBJECTIVITY SCORE (TextBlob): 0.42170835337501994
# -----------------------
# Extracted and saved: extracted_texts/blackassign0089.txt
# URL_ID: blackassign0089
# URL: https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/
# AVG SENTENCE LENGTH: 22.25
# PERCENTAGE OF COMPLEX WORDS: 56.61252900232019
# FOG INDEX: 31.545011600928078
# AVG NUMBER OF WORDS PER SENTENCE: 22.25
# COMPLEX WORD COUNT: 244
# WORD COUNT: 431
# SYLLABLE PER WORD: 2.320185614849188
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 7.1183294663573085
# POLARITY SCORE (Custom): -0.4482758543400715
# SUBJECTIVITY SCORE (Custom): 0.13457076534902374
# POLARITY SCORE (TextBlob): 0.08094531419873882
# SUBJECTIVITY SCORE (TextBlob): 0.439496629702109
# -----------------------
# Extracted and saved: extracted_texts/blackassign0090.txt
# URL_ID: blackassign0090
# URL: https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/
# AVG SENTENCE LENGTH: 18.273972602739725
# PERCENTAGE OF COMPLEX WORDS: 49.007936507936506
# FOG INDEX: 26.91276364427049
# AVG NUMBER OF WORDS PER SENTENCE: 18.273972602739725
# COMPLEX WORD COUNT: 247
# WORD COUNT: 504
# SYLLABLE PER WORD: 2.255952380952381
# PERSONAL PRONOUNS: 45
# AVG WORD LENGTH: 6.996031746031746
# POLARITY SCORE (Custom): -0.14634146162998218
# SUBJECTIVITY SCORE (Custom): 0.1626984123755984
# POLARITY SCORE (TextBlob): 0.11541107352031724
# SUBJECTIVITY SCORE (TextBlob): 0.44506220670086244
# -----------------------
# Extracted and saved: extracted_texts/blackassign0091.txt
# URL_ID: blackassign0091
# URL: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/
# AVG SENTENCE LENGTH: 31.405405405405407
# PERCENTAGE OF COMPLEX WORDS: 56.102783725910065
# FOG INDEX: 35.00327565252619
# AVG NUMBER OF WORDS PER SENTENCE: 31.405405405405407
# COMPLEX WORD COUNT: 262
# WORD COUNT: 467
# SYLLABLE PER WORD: 2.3704496788008567
# PERSONAL PRONOUNS: 15
# AVG WORD LENGTH: 7.122055674518201
# POLARITY SCORE (Custom): -0.07999999840000004
# SUBJECTIVITY SCORE (Custom): 0.10706638092705272
# POLARITY SCORE (TextBlob): 0.07701032059727714
# SUBJECTIVITY SCORE (TextBlob): 0.432465963987703
# -----------------------
# Extracted and saved: extracted_texts/blackassign0092.txt
# URL_ID: blackassign0092
# URL: https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/
# AVG SENTENCE LENGTH: 24.107142857142858
# PERCENTAGE OF COMPLEX WORDS: 52.131147540983605
# FOG INDEX: 30.49531615925059
# AVG NUMBER OF WORDS PER SENTENCE: 24.107142857142858
# COMPLEX WORD COUNT: 318
# WORD COUNT: 610
# SYLLABLE PER WORD: 2.3065573770491805
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 7.075409836065574
# POLARITY SCORE (Custom): -0.3333333277777779
# SUBJECTIVITY SCORE (Custom): 0.09836065557645794
# POLARITY SCORE (TextBlob): 0.07886309831267219
# SUBJECTIVITY SCORE (TextBlob): 0.3305119375573921
# -----------------------
# Extracted and saved: extracted_texts/blackassign0093.txt
# URL_ID: blackassign0093
# URL: https://insights.blackcoffer.com/travel-and-tourism-outlook/
# AVG SENTENCE LENGTH: 20.5
# PERCENTAGE OF COMPLEX WORDS: 37.3134328358209
# FOG INDEX: 23.12537313432836
# AVG NUMBER OF WORDS PER SENTENCE: 20.5
# COMPLEX WORD COUNT: 25
# WORD COUNT: 67
# SYLLABLE PER WORD: 2.029850746268657
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 6.343283582089552
# POLARITY SCORE (Custom): 0.1428571224489825
# SUBJECTIVITY SCORE (Custom): 0.10447761038093119
# POLARITY SCORE (TextBlob): 0.27325487012987015
# SUBJECTIVITY SCORE (TextBlob): 0.42491206709956714
# -----------------------
# Extracted and saved: extracted_texts/blackassign0094.txt
# URL_ID: blackassign0094
# URL: https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/
# AVG SENTENCE LENGTH: 20.548387096774192
# PERCENTAGE OF COMPLEX WORDS: 47.93233082706767
# FOG INDEX: 27.392287169536747
# AVG NUMBER OF WORDS PER SENTENCE: 20.548387096774192
# COMPLEX WORD COUNT: 255
# WORD COUNT: 532
# SYLLABLE PER WORD: 2.107142857142857
# PERSONAL PRONOUNS: 24
# AVG WORD LENGTH: 6.701127819548872
# POLARITY SCORE (Custom): -0.19999999750000003
# SUBJECTIVITY SCORE (Custom): 0.15037593956696252
# POLARITY SCORE (TextBlob): 0.07338395111832612
# SUBJECTIVITY SCORE (TextBlob): 0.44245129870129857
# -----------------------
# Extracted and saved: extracted_texts/blackassign0095.txt
# URL_ID: blackassign0095
# URL: https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/
# AVG SENTENCE LENGTH: 20.970588235294116
# PERCENTAGE OF COMPLEX WORDS: 50.3448275862069
# FOG INDEX: 28.526166328600404
# AVG NUMBER OF WORDS PER SENTENCE: 20.970588235294116
# COMPLEX WORD COUNT: 146
# WORD COUNT: 290
# SYLLABLE PER WORD: 2.193103448275862
# PERSONAL PRONOUNS: 7
# AVG WORD LENGTH: 6.810344827586207
# POLARITY SCORE (Custom): -0.5151514995408637
# SUBJECTIVITY SCORE (Custom): 0.11379310305588586
# POLARITY SCORE (TextBlob): 0.05948027068716724
# SUBJECTIVITY SCORE (TextBlob): 0.4058518110242248
# -----------------------
# Extracted and saved: extracted_texts/blackassign0096.txt
# URL_ID: blackassign0096
# URL: https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/
# AVG SENTENCE LENGTH: 24.1
# PERCENTAGE OF COMPLEX WORDS: 58.7037037037037
# FOG INDEX: 33.12148148148148
# AVG NUMBER OF WORDS PER SENTENCE: 24.1
# COMPLEX WORD COUNT: 317
# WORD COUNT: 540
# SYLLABLE PER WORD: 2.390740740740741
# PERSONAL PRONOUNS: 3
# AVG WORD LENGTH: 7.261111111111111
# POLARITY SCORE (Custom): -0.35714285289115655
# SUBJECTIVITY SCORE (Custom): 0.1555555552674897
# POLARITY SCORE (TextBlob): 0.05715384749658943
# SUBJECTIVITY SCORE (TextBlob): 0.3914643689643688
# -----------------------
# Extracted and saved: extracted_texts/blackassign0097.txt
# URL_ID: blackassign0097
# URL: https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/
# AVG SENTENCE LENGTH: 32.270270270270274
# PERCENTAGE OF COMPLEX WORDS: 46.28712871287129
# FOG INDEX: 31.42295959325662
# AVG NUMBER OF WORDS PER SENTENCE: 32.270270270270274
# COMPLEX WORD COUNT: 187
# WORD COUNT: 404
# SYLLABLE PER WORD: 2.146039603960396
# PERSONAL PRONOUNS: 13
# AVG WORD LENGTH: 6.7004950495049505
# POLARITY SCORE (Custom): -0.24999999553571436
# SUBJECTIVITY SCORE (Custom): 0.138613861043035
# POLARITY SCORE (TextBlob): 0.06488935574229694
# SUBJECTIVITY SCORE (TextBlob): 0.4411360698125404
# -----------------------
# Extracted and saved: extracted_texts/blackassign0098.txt
# URL_ID: blackassign0098
# URL: https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/
# AVG SENTENCE LENGTH: 32.2
# PERCENTAGE OF COMPLEX WORDS: 41.66666666666667
# FOG INDEX: 29.54666666666667
# AVG NUMBER OF WORDS PER SENTENCE: 32.2
# COMPLEX WORD COUNT: 35
# WORD COUNT: 84
# SYLLABLE PER WORD: 2.1666666666666665
# PERSONAL PRONOUNS: 0
# AVG WORD LENGTH: 6.666666666666667
# POLARITY SCORE (Custom): 0.0
# SUBJECTIVITY SCORE (Custom): 0.0
# POLARITY SCORE (TextBlob): 0.0391025641025641
# SUBJECTIVITY SCORE (TextBlob): 0.375
# -----------------------
# Extracted and saved: extracted_texts/blackassign0099.txt
# URL_ID: blackassign0099
# URL: https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/
# AVG SENTENCE LENGTH: 22.185185185185187
# PERCENTAGE OF COMPLEX WORDS: 45.92274678111588
# FOG INDEX: 27.24317278652043
# AVG NUMBER OF WORDS PER SENTENCE: 22.185185185185187
# COMPLEX WORD COUNT: 107
# WORD COUNT: 233
# SYLLABLE PER WORD: 2.07725321888412
# PERSONAL PRONOUNS: 5
# AVG WORD LENGTH: 6.532188841201717
# POLARITY SCORE (Custom): 0.6249999609375024
# SUBJECTIVITY SCORE (Custom): 0.06866952760227671
# POLARITY SCORE (TextBlob): 0.08413525498891351
# SUBJECTIVITY SCORE (TextBlob): 0.4035587583148557
# -----------------------
# Extracted and saved: extracted_texts/blackassign0100.txt
# URL_ID: blackassign0100
# URL: https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/
# AVG SENTENCE LENGTH: 34.333333333333336
# PERCENTAGE OF COMPLEX WORDS: 58.35351089588377
# FOG INDEX: 37.07473769168685
# AVG NUMBER OF WORDS PER SENTENCE: 34.333333333333336
# COMPLEX WORD COUNT: 241
# WORD COUNT: 413
# SYLLABLE PER WORD: 2.3292978208232444
# PERSONAL PRONOUNS: 4
# AVG WORD LENGTH: 7.171912832929782
# POLARITY SCORE (Custom): -0.32530120089998554
# SUBJECTIVITY SCORE (Custom): 0.2009685225158147
# POLARITY SCORE (TextBlob): 0.08028635044764076
# SUBJECTIVITY SCORE (TextBlob): 0.422876615618551
# -----------------------
# Output_Data_Structure.xlsx

# %%
results_df = pd.DataFrame(results, columns=columns)
results_df.to_excel('Output_Data_Structure.xlsx', index=False)
print("Data successfully updated in Output_Data_Structure.xlsx")
# Out:
# Data successfully updated in Output_Data_Structure.xlsx
